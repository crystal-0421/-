# %% [markdown]
# ## 1. 读取数据

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('data/双十一淘宝美妆数据.csv')
data.head()
# Out:
#   update_time            id                                  title  price  \
# 0  2016/11/14  A18164178225    CHANDO/自然堂 雪域精粹纯粹滋润霜50g 补水保湿 滋润水润面霜  139.0
# 1  2016/11/14  A18177105952   CHANDO/自然堂凝时鲜颜肌活乳液120ML 淡化细纹补水滋润专柜正品  194.0
# 2  2016/11/14  A18177226992   CHANDO/自然堂活泉保湿修护精华水（滋润型135ml 补水控油爽肤水   99.0
# 3  2016/11/14  A18178033846  CHANDO/自然堂 男士劲爽控油洁面膏 100g 深层清洁  男士洗面奶   38.0
# 4  2016/11/14  A18178045259     CHANDO/自然堂雪域精粹纯粹滋润霜（清爽型）50g补水保湿滋润霜  139.0
#
#    sale_count  comment_count   店名
# 0     26719.0         2704.0  自然堂
# 1      8122.0         1492.0  自然堂
# 2     12668.0          589.0  自然堂
# 3     25805.0         4287.0  自然堂
# 4      5196.0          618.0  自然堂

# %%
data.shape
# Out:
# (27598, 7)

# %%
# 查看各字段信息
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27598 entries, 0 to 27597
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   update_time    27598 non-null  object
#  1   id             27598 non-null  object
#  2   title          27598 non-null  object
#  3   price          27598 non-null  float64
#  4   sale_count     25244 non-null  float64
#  5   comment_count  25244 non-null  float64
#  6   店名             27598 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 1.5+ MB

# %%
data['店名'].value_counts()
# Out:
# 悦诗风吟    3021
# 佰草集     2265
# 欧莱雅     1974
# 雅诗兰黛    1810
# 倩碧      1704
# 美加净     1678
# 欧珀莱     1359
# 妮维雅     1329
# 相宜本草    1313
# 兰蔻      1285
# 娇兰      1193
# 自然堂     1190
# 玉兰油     1135
# 兰芝      1091
# 美宝莲      825
# 资生堂      821
# 植村秀      750
# 薇姿       746
# 雅漾       663
# 雪花秀      543
# SKII     469
# 蜜丝佛陀     434
# Name: 店名, dtype: int64

# %% [markdown]
# ## 2. 数据清洗
# ### 2.1 重复数据处理

# %%
# 对重复数据做删除处理
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (27512, 7)

# %%
# 删除重复数据之后，索引未变，因此应该进行索引重置
data.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### 2.2 缺失值处理

# %%
# 查看缺失值
data.isnull().sum()
# Out:
# update_time         0
# id                  0
# title               0
# price               0
# sale_count       2350
# comment_count    2350
# 店名                  0
# dtype: int64

# %% [markdown]
# * 有两列数据存在缺失值：sale_count,comment_count

# %%
# 查看数据结构
data.describe()
# Out:
#               price    sale_count  comment_count
# count  27512.000000  2.516200e+04   25162.000000
# mean     363.423512  1.231605e+04    1121.741197
# std      614.876153  5.241236e+04    5277.781581
# min        1.000000  0.000000e+00       0.000000
# 25%       99.000000  2.780000e+02      21.000000
# 50%      205.000000  1.443000e+03     153.000000
# 75%      390.000000  6.353000e+03     669.000000
# max    11100.000000  1.923160e+06  202930.000000

# %%
# 查看sale_count列的众数
mode_01 = data.sale_count.mode()
mode_01
# Out:
# 0    0.0
# dtype: float64

# %%
# 查看comment_count列的众数
mode_02 = data.comment_count.mode()
mode_02
# Out:
# 0    0.0
# dtype: float64

# %% [markdown]
# * 此处两列的众数均为0，且由标签数据含义可知销售量和评论数有可能存在为0的情况，因此使用0来填充缺失值。

# %%
data.fillna(0, inplace=True)

# %%
data.isnull().sum()
# Out:
# update_time      0
# id               0
# title            0
# price            0
# sale_count       0
# comment_count    0
# 店名               0
# dtype: int64

# %% [markdown]
# ### 2.3 提取表格中有用信息并新增为列
# #### （1）对商品标题进行分词处理

# %%
import jieba

# %%
# jieba.load_userdict('addwords.txt')

title_cut = []
for i in data.title:
    j = jieba.lcut(i)
    title_cut.append(j)
title_cut
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.690 seconds.
# Prefix dict has been built successfully.
# [['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '滋润霜',
#   '50g',
#   ' ',
#   '补水',
#   '保湿',
#   ' ',
#   '滋润',
#   '水润',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '乳液',
#   '120ML',
#   ' ',
#   '淡化',
#   '细纹',
#   '补水',
#   '滋润',
#   '专柜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '活泉',
#   '保湿',
#   '修护',
#   '精华',
#   '水',
#   '（',
#   '滋润',
#   '型',
#   '135ml',
#   ' ',
#   '补水',
#   '控油',
#   '爽肤水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '男士',
#   '劲爽',
#   '控油',
#   '洁面膏',
#   ' ',
#   '100g',
#   ' ',
#   '深层',
#   '清洁',
#   ' ',
#   ' ',
#   '男士',
#   '洗面奶'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '滋润霜',
#   '（',
#   '清爽型',
#   '）',
#   '50g',
#   '补水',
#   '保湿',
#   '滋润霜'],
#  ['自然',
#   '堂',
#   ' ',
#   '雪域',
#   '纯粹',
#   '滋润',
#   '洗颜霜',
#   ' ',
#   '110g',
#   ' ',
#   ' ',
#   '补水',
#   '保湿',
#   ' ',
#   ' ',
#   '洗面奶',
#   '女',
#   ' ',
#   '深层',
#   '清洁'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白晶',
#   '采霜',
#   '（',
#   '滋润',
#   '型',
#   '）',
#   '50g',
#   ' ',
#   '滋润',
#   '修护',
#   '面霜',
#   ' ',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '深层',
#   '净化',
#   '控油',
#   '凝露',
#   '60g',
#   ' ',
#   '控油',
#   '补水',
#   '保湿',
#   '滋润',
#   ' ',
#   '活泉',
#   '精华',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '修护',
#   '精华液',
#   '35ml',
#   ' ',
#   '淡化',
#   '细纹',
#   '护肤',
#   '精华'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '活泉',
#   '保湿',
#   '精华',
#   '套装',
#   ' ',
#   '保湿',
#   '补水',
#   '滋润',
#   '控油',
#   '面部',
#   '护理',
#   '套装'],
#  ['自然',
#   '堂',
#   ' ',
#   '水润',
#   '保湿',
#   '柔肤水',
#   ' ',
#   '135ml',
#   ' ',
#   '补水',
#   '保湿',
#   '清透锁',
#   '水',
#   ' ',
#   '专柜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿霜',
#   '50g',
#   ' ',
#   '补水',
#   '保湿',
#   '锁水',
#   '细腻',
#   '清爽',
#   '防',
#   '干燥',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '长效',
#   '保湿霜',
#   '50g',
#   ' ',
#   '深层',
#   '补水',
#   '持久',
#   '锁水',
#   '细腻',
#   '清爽',
#   '滋润'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '男士',
#   '面部',
#   '护肤',
#   '套装',
#   ' ',
#   ' ',
#   '洁面',
#   '洗面奶',
#   '爽肤水',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润',
#   '深澈',
#   '精华',
#   '面膜',
#   '贴',
#   '5',
#   '片',
#   ' ',
#   '补水',
#   '面膜',
#   '护肤品',
#   '专柜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '嫩白',
#   '保湿霜',
#   '50g',
#   ' ',
#   ' ',
#   '保湿',
#   '补水',
#   '滋润',
#   '清',
#   '保湿霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   ' ',
#   '保湿',
#   '乳',
#   '100ML',
#   ' ',
#   '持久',
#   '保湿',
#   '水嫩',
#   '肌肤',
#   '补水',
#   ' ',
#   '乳液'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白水',
#   '乳',
#   '套装',
#   ' ',
#   '爽肤水',
#   '乳液',
#   '面膜',
#   ' ',
#   '亮肤',
#   '补水',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '套装',
#   '水乳',
#   '/',
#   '霜',
#   '套装',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '淡化',
#   '细纹'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '冰肌',
#   '精华',
#   '套组',
#   ' ',
#   '滋润',
#   '护肤',
#   ' ',
#   '精华',
#   '爽肤水',
#   'BB',
#   '套装'],
#  ['自然', '堂水润', '保湿', '洁面', '套装', ' ', '深层', '清洁', '不', '紧绷', '补水', '保湿', '洁面'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿',
#   '面膜',
#   '5',
#   '片装',
#   ' ',
#   '滋润',
#   '补水',
#   '保湿',
#   '面膜',
#   '贴',
#   ' ',
#   '包邮',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '粉嫩',
#   '保湿',
#   '面膜',
#   '面贴膜',
#   '5',
#   '片',
#   ' ',
#   ' ',
#   '密集',
#   '补水',
#   '修护',
#   '面膜',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '密集',
#   '修护',
#   '滋润',
#   '冰肌',
#   '膜',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '面膜'],
#  ['自然',
#   '堂',
#   '男士',
#   '保湿',
#   '补水',
#   '霜',
#   '矿物',
#   '元素',
#   '滋润',
#   '肌肤',
#   '面霜',
#   '护肤品',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '滋润',
#   '乳液',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '修护',
#   '乳液',
#   '护肤'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润',
#   '晶采',
#   '眼霜',
#   '15g',
#   ' ',
#   '淡化',
#   '黑眼圈',
#   '细纹',
#   '紧致',
#   ' ',
#   '眼部',
#   '护理',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '深层',
#   '补水',
#   '露',
#   ' ',
#   '补水',
#   '保湿',
#   ' ',
#   '平衡',
#   '油性',
#   '肌肤',
#   '化妆品',
#   '护肤',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '眼部',
#   '精华',
#   '乳',
#   '18g',
#   '淡化',
#   '细纹',
#   '黑眼圈',
#   '滋润',
#   '眼霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   'BB',
#   '家族',
#   '润泽',
#   '无瑕',
#   '养护',
#   '粉底液',
#   '遮',
#   '瑕',
#   '粉底液',
#   '遮',
#   '瑕',
#   '调整',
#   '肤色'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '水乳',
#   '套装',
#   ' ',
#   '爽肤水',
#   '冰肌',
#   '水',
#   '乳液',
#   '面霜',
#   '护理',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿',
#   '面部',
#   '护理',
#   '套装',
#   ' ',
#   '洗面奶',
#   '爽肤水',
#   '乳液',
#   '面霜',
#   '补水',
#   '女'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '雪润皙',
#   '白',
#   '冰肌',
#   '水送',
#   '面膜',
#   '补水',
#   '保湿',
#   '修护',
#   '爽肤水',
#   '化妆水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '冰肌',
#   '水',
#   '（',
#   '凝润型',
#   '）',
#   '保湿',
#   '补水',
#   '修护',
#   '滋润',
#   ' ',
#   '爽肤水'],
#  ['自然',
#   '堂',
#   ' ',
#   '凝',
#   '时鲜',
#   '颜',
#   '洁面霜',
#   '110g',
#   ' ',
#   '洁面',
#   '保湿',
#   '滋润',
#   '不',
#   '紧绷',
#   ' ',
#   '洗面奶',
#   '专柜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '滋润',
#   '精华液',
#   ' ',
#   '补水',
#   '保湿',
#   '修护',
#   '滋润',
#   '精华液'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '男士',
#   '保湿',
#   '精华',
#   '眼霜',
#   '淡化',
#   '黑眼圈',
#   '细纹',
#   '紧致',
#   '眼部',
#   '护理',
#   '正品'],
#  ['自然',
#   '堂',
#   '男士',
#   '冰川',
#   '控油',
#   '爽肤水',
#   ' ',
#   '补水',
#   '保湿',
#   '控油',
#   '须',
#   '后',
#   '水',
#   '正品',
#   '包邮'],
#  ['自然',
#   '堂',
#   ' ',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '眼霜',
#   '15g',
#   ' ',
#   '淡化',
#   '黑眼圈',
#   '细纹',
#   ' ',
#   '保湿',
#   ' ',
#   '专柜',
#   '正品'],
#  ['自然',
#   '堂',
#   '男士',
#   '控油',
#   '补水',
#   '露',
#   ' ',
#   '补水',
#   '保湿',
#   '控油',
#   '清爽',
#   '男士',
#   '护肤品',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '补水',
#   '控油',
#   '洁面膏',
#   '（',
#   '泡沫',
#   '型',
#   '）',
#   '110g',
#   ' ',
#   ' ',
#   '深层',
#   '清洁',
#   ' ',
#   '正品',
#   ' ',
#   '包邮'],
#  ['自然',
#   '堂',
#   ' ',
#   '雪润',
#   '深澈',
#   '皙',
#   '白',
#   '精华液',
#   '40ml',
#   ' ',
#   '保湿',
#   '滋润',
#   ' ',
#   '美白',
#   '精华',
#   ' ',
#   '面部',
#   '精华',
#   '正品'],
#  ['专柜',
#   '正品',
#   '自然',
#   '堂',
#   ' ',
#   '活泉',
#   '加倍',
#   '保湿霜',
#   '50g',
#   ' ',
#   '补水',
#   '锁水',
#   '减少',
#   '细纹',
#   '滋润',
#   '肌肤'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '滋润',
#   '保湿',
#   '精华',
#   '霜',
#   'BB',
#   '霜',
#   '35ml',
#   ' ',
#   '补水',
#   '保湿',
#   '隔离',
#   'BB',
#   '霜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润',
#   '深澈',
#   '皙',
#   '白',
#   '补水',
#   '套装',
#   ' ',
#   '洗面奶',
#   '冰肌',
#   '水',
#   '乳液',
#   '补水',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '冰肌',
#   '滋润',
#   '套装',
#   ' ',
#   '洗面奶',
#   '爽肤水',
#   '乳液',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白',
#   '精华',
#   '套装',
#   ' ',
#   '美白',
#   '保湿',
#   '补水',
#   '滋润',
#   '护理',
#   '爽肤水',
#   '精华'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂凝时',
#   '休眠',
#   '霜',
#   '（',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '霜',
#   '淡化',
#   '细纹',
#   '面霜'],
#  ['自然',
#   '堂',
#   ' ',
#   '专柜',
#   '正品',
#   ' ',
#   '水润',
#   '保湿',
#   '柔肤',
#   '乳',
#   ' ',
#   '清透',
#   '补水',
#   '保湿',
#   '乳液',
#   '清透',
#   '补水',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
#   '嫩白',
#   '保湿',
#   '柔肤水',
#   ' ',
#   '135ml',
#   ' ',
#   '娇颜亮',
#   '润',
#   '升级',
#   ' ',
#   '正品',
#   '包邮',
#   ' ',
#   '保湿',
#   '爽肤水'],
#  ['自然',
#   '堂娇颜',
#   ' ',
#   '保湿',
#   '精华液',
#   ' ',
#   '30ml',
#   ' ',
#   '保湿',
#   '补水',
#   '提亮',
#   '肤色',
#   ' ',
#   '面部',
#   '精华'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '嫩白',
#   '保湿霜',
#   '（',
#   '清爽型',
#   '）',
#   '50g',
#   '玫瑰',
#   '原液',
#   '补水',
#   '保湿',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿',
#   '洗颜霜',
#   '(',
#   '干性',
#   '肌肤',
#   '适用',
#   ')',
#   ' ',
#   '100g',
#   '补水',
#   '保湿',
#   '洗面奶'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿',
#   '洗颜霜',
#   ' ',
#   '专柜',
#   '正品',
#   ' ',
#   '洗面奶',
#   '女',
#   ' ',
#   '深层',
#   '清洁',
#   '不',
#   '紧绷'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '嫩白',
#   '基础',
#   '三件',
#   '套装',
#   '面部',
#   '护理',
#   '套装',
#   ' ',
#   '滋润',
#   '保湿',
#   '补水',
#   '女'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '冰肌',
#   '水',
#   ' ',
#   ' ',
#   '淡化',
#   '细纹',
#   '补水',
#   '保湿',
#   '清爽',
#   '修护',
#   '爽肤水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '冰肌',
#   '水',
#   '清润',
#   '型',
#   ' ',
#   ' ',
#   '补水',
#   '保湿',
#   '修护',
#   '爽肤水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂光',
#   '透',
#   '无瑕',
#   '矿物',
#   '养护',
#   '两用',
#   '粉饼',
#   '保湿',
#   '修护',
#   '遮',
#   '瑕',
#   '定妆',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂果',
#   '漾莹亮',
#   '养护',
#   '唇彩',
#   ' ',
#   '持久',
#   '保湿',
#   '滋润',
#   '唇膏',
#   '口红',
#   '彩'],
#  ['自然',
#   '堂',
#   '男士',
#   '洁面',
#   '2',
#   '支装',
#   ' ',
#   '深层',
#   '清洁',
#   '清爽',
#   '控油',
#   '洗面奶',
#   '男士',
#   '正品'],
#  ['自然', '堂植萃', '净澈', '养护', '眼唇', '卸妆液', '深层', '清洁', '眼部', '唇部', '正品', '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂晶透',
#   '无瑕',
#   '散粉',
#   '蜜粉',
#   '定妆',
#   '粉',
#   ' ',
#   '控油',
#   '保湿',
#   '光泽',
#   '美肌',
#   '彩妆',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '翘密',
#   '.',
#   '纤长',
#   '随心',
#   '控',
#   '睫毛膏',
#   '黑色',
#   ' ',
#   '浓密',
#   '卷',
#   '翘',
#   '持久',
#   '定型',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂亲',
#   '蜜亮',
#   '彩',
#   '唇膏',
#   '笔护唇',
#   ' ',
#   '保湿',
#   '滋养',
#   '多色',
#   '口红',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂植萃',
#   '净澈',
#   '养护',
#   '卸妆乳',
#   ' ',
#   '脸部',
#   '卸妆',
#   '温和',
#   '舒缓',
#   '彩妆',
#   '正品',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '深邃',
#   '精致',
#   '眼线笔',
#   '黑色',
#   ' ',
#   '持久',
#   '不',
#   '黏腻',
#   '眼部',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '粉嫩',
#   '眼霜',
#   '套装',
#   ' ',
#   '水嫩',
#   '肌肤',
#   ' ',
#   '爽肤水',
#   '乳液',
#   '眼霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白晶采',
#   '日霜',
#   '50g',
#   ' ',
#   'SPF15',
#   '/',
#   'PA',
#   '++',
#   ' ',
#   '轻透',
#   '保湿',
#   '滋润',
#   '修护'],
#  ['自然',
#   '堂',
#   ' ',
#   '雪润皙',
#   '白',
#   '密集',
#   '修护',
#   '晚霜',
#   ' ',
#   '50g',
#   ' ',
#   '夜间',
#   '修护',
#   '补水',
#   '加倍',
#   '护理',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '嫩肤',
#   '保湿',
#   '精华',
#   '套装',
#   ' ',
#   '滋润',
#   '保湿',
#   '补水',
#   '面部',
#   '护理',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '保湿',
#   '补水',
#   '滋润',
#   '呵护',
#   '套装',
#   ' ',
#   '护肤品',
#   '套装',
#   '女',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白日',
#   '晚霜',
#   '套装',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '面霜',
#   '套'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '滋润',
#   '礼盒',
#   '15',
#   '周年',
#   '定制',
#   '纪念版',
#   '套装'],
#  ['自然',
#   '堂',
#   '自动',
#   '双头',
#   '易画',
#   '眼线笔',
#   ' ',
#   '帖服',
#   '持久',
#   '不',
#   '晕染',
#   '眼线笔',
#   ' ',
#   '眼部'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '炫彩盈',
#   '润唇膏',
#   ' ',
#   '滋润',
#   '保湿',
#   '持久',
#   '唇膏',
#   '多色',
#   '口红',
#   '女',
#   ' ',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '修护',
#   '眼霜',
#   '15g',
#   ' ',
#   '去',
#   '淡化',
#   '黑眼圈',
#   '眼袋',
#   '细纹'],
#  ['自然',
#   '堂',
#   '雪域',
#   '倍护',
#   '防晒霜',
#   'SPF30',
#   '+',
#   'PA',
#   '+++',
#   '隔离',
#   '保湿',
#   '防晒',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '轻盈',
#   '身体',
#   '防晒乳',
#   '（',
#   '喷雾',
#   '型',
#   '）',
#   'SPF30',
#   '/',
#   'PA',
#   '++',
#   '防晒'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '雪域',
#   '冰肌',
#   '晒',
#   '后',
#   '修护露',
#   ' ',
#   '保湿',
#   '晒',
#   '后',
#   '修护',
#   '清爽',
#   '补水',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润晶',
#   '采裸透',
#   '气垫',
#   '霜',
#   ' ',
#   '保湿',
#   '水润',
#   '贴',
#   '妆',
#   '遮',
#   '瑕',
#   ' ',
#   '气垫',
#   'BB',
#   '霜'],
#  ['自然',
#   '堂亮',
#   '眸',
#   '持久',
#   '眼线',
#   '膏',
#   ' ',
#   ' ',
#   '持久',
#   '防水',
#   '不',
#   '晕染',
#   '速',
#   '干眼',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜淡斑',
#   '精华液',
#   '40ml',
#   '淡化',
#   '干纹',
#   '细纹',
#   '滋润',
#   '精华',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
#   '雪润晶',
#   '采裸透',
#   '气垫',
#   '霜',
#   '（',
#   '替换',
#   '装',
#   '）',
#   '保湿',
#   '修颜水润',
#   '贴',
#   '妆',
#   ' ',
#   '气垫',
#   'BB',
#   '霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '男士',
#   ' ',
#   '控油',
#   '活炭',
#   '抗',
#   '黑头',
#   '洁面膏',
#   ' ',
#   '清洁',
#   '保湿',
#   '控油',
#   ' ',
#   '洗面奶'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '男士',
#   '控油',
#   '柔珠',
#   '深层',
#   '洁面',
#   'ㄠ',
#   ' ',
#   '清爽',
#   '控油',
#   '不',
#   '紧绷',
#   '洗面奶'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润晶',
#   '采裸透',
#   '气垫',
#   '霜',
#   '+',
#   '替换',
#   '装',
#   '保湿',
#   '水润',
#   '贴',
#   '妆',
#   'BB',
#   '霜',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '定制',
#   '礼盒',
#   ' ',
#   '淡化',
#   '细纹',
#   '干纹',
#   ' ',
#   '滋润',
#   '精华',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '保湿',
#   '滋润',
#   ' ',
#   '呵护',
#   '套装',
#   ' ',
#   '补水',
#   '乳霜',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '粉嫩',
#   '保湿',
#   '眼霜',
#   '20g',
#   ' ',
#   '淡化',
#   '黑眼圈',
#   '细纹',
#   ' ',
#   '保湿',
#   '专柜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '粉嫩',
#   '洁肤',
#   '霜',
#   ' ',
#   '100g',
#   '深层',
#   '清洁',
#   '补水',
#   ' ',
#   '洗面奶',
#   '女',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   ' ',
#   '滋润',
#   '补水',
#   '呵护',
#   '臻',
#   '选',
#   '套装',
#   ' ',
#   '淡化',
#   '细纹',
#   '补水',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '彩妆',
#   '护肤',
#   '组合',
#   '套装',
#   ' ',
#   '唇膏',
#   '眼线笔',
#   ' ',
#   '滋润',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '滋润',
#   '滋养',
#   '护唇膏',
#   ' ',
#   '保湿',
#   '滋润',
#   '修护',
#   '干裂',
#   '润唇膏',
#   ' ',
#   '补水',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '护手霜',
#   '3',
#   '支装',
#   '套装',
#   '面膜',
#   ' ',
#   '滋润',
#   '保湿',
#   ' ',
#   '防裂',
#   '修护',
#   '护手霜',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '鲜嫩',
#   '保湿',
#   '护手霜',
#   '50g',
#   '保湿',
#   '补水',
#   ' ',
#   '改善',
#   '干裂',
#   ' ',
#   ' ',
#   '护手霜',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '柔润',
#   '细嫩',
#   '护手霜',
#   '50g',
#   ' ',
#   '滋润',
#   '保湿',
#   '补水',
#   '嫩肤',
#   ' ',
#   '护手霜',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '冰肌',
#   '水',
#   '（',
#   '滋润',
#   '型',
#   '）',
#   '淡化',
#   '细纹',
#   '补水',
#   '滋润',
#   '爽肤水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '立体',
#   '塑形',
#   '双头',
#   '眉笔',
#   ' ',
#   '修饰',
#   '眉部',
#   '轮廓',
#   '调整',
#   '眉形',
#   '彩妆',
#   '女',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂凝时',
#   '肌活',
#   '修纹',
#   '精华',
#   '霜',
#   'SPF30',
#   '++',
#   '修纹',
#   '遮',
#   '瑕',
#   '补水',
#   '保湿',
#   'BB',
#   '霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '抗皱',
#   '精华液',
#   '40ml',
#   ' ',
#   '小',
#   'V',
#   '脸',
#   '提升',
#   '轮廓',
#   '淡化',
#   '皱纹'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '抗皱',
#   '滋养',
#   '乳液',
#   '120ml',
#   ' ',
#   '滋润',
#   '保湿',
#   '肌肤',
#   '弹性',
#   '轮廓'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '抗皱',
#   '气色',
#   '液',
#   '160ml',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '爽肤水',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '抗皱',
#   '滋养',
#   '早安',
#   '霜',
#   '50g',
#   ' ',
#   '日间',
#   '防护',
#   '肌肤',
#   '弹性',
#   '滋润'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润',
#   '深澈洁',
#   '面膏',
#   ' ',
#   '110g',
#   ' ',
#   '深层',
#   '清洁',
#   '不',
#   '紧绷',
#   ' ',
#   '洗面奶',
#   '女'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '多重',
#   '隔离',
#   '防晒乳',
#   'SPF30',
#   '+',
#   '/',
#   'PA',
#   '++',
#   '隔离',
#   '保湿',
#   '自然',
#   '堂',
#   '防晒霜',
#   '女'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '多重',
#   '隔离',
#   '防晒乳',
#   'SPF20',
#   '/',
#   'PA',
#   '++',
#   ' ',
#   '隔离',
#   ' ',
#   '保湿',
#   '防晒霜',
#   '女',
#   '男'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白晶',
#   '采乳',
#   '120ML',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '乳液',
#   ' ',
#   '专柜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '亲蜜',
#   '莹润',
#   '柔彩',
#   '唇膏',
#   '笔',
#   '2.5',
#   'g',
#   ' ',
#   '水感',
#   '亮泽',
#   ' ',
#   '柔滑',
#   '不',
#   '粘腻'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '滋润',
#   '补水',
#   '礼盒',
#   '套装',
#   ' ',
#   '洗面奶',
#   '爽肤水',
#   '乳液',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白',
#   '多重',
#   '防晒',
#   '隔离霜',
#   ' ',
#   'SPF30',
#   '+',
#   '/',
#   'PA',
#   '+++',
#   ' ',
#   '滋润',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '补水',
#   '嫩肤',
#   '面膜',
#   '组合',
#   '21',
#   '片',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '净透',
#   '冰肌',
#   '角质',
#   '调理',
#   '凝露',
#   ' ',
#   '去除',
#   '老废',
#   '角质'],
#  ['自然',
#   '堂轻透',
#   '无瑕',
#   '修颜霜',
#   'SPF25',
#   ' ',
#   'PA',
#   '++',
#   ' ',
#   '多效',
#   'BB',
#   ' ',
#   '防晒',
#   '隔离',
#   '均匀',
#   '肤色'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂轻透',
#   '无瑕',
#   '修颜霜',
#   'SPF20',
#   ' ',
#   'PA',
#   '++',
#   '（',
#   '润白亮',
#   '采',
#   '）',
#   'BB',
#   '霜',
#   '修颜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '水润',
#   '套装',
#   ' ',
#   '补水',
#   '紧致',
#   '滋养',
#   '深层',
#   '滋养',
#   '修护',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   'V',
#   '脸',
#   '滋养',
#   '套装',
#   ' ',
#   '紧致',
#   '肌肤',
#   '洗面奶',
#   '+',
#   '乳液',
#   '爽肤水',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '雪域',
#   '紫草',
#   '细致',
#   '毛孔',
#   '亮润',
#   '面膜',
#   '8',
#   '片装',
#   ' ',
#   '补水',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '雪域',
#   '补水',
#   '保湿',
#   '面膜',
#   '26',
#   '片',
#   '平衡',
#   '油脂',
#   '细致',
#   '毛孔'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '雪莲',
#   '舒缓',
#   '多效',
#   '保湿',
#   '面膜',
#   '16',
#   '片',
#   ' ',
#   '肌肤',
#   '水润',
#   '舒适'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '雪域',
#   '龙胆',
#   '亮润',
#   '面膜',
#   '5',
#   '片装',
#   ' ',
#   '提亮',
#   '肤色',
#   '水润',
#   '透亮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '多效',
#   '补水',
#   '保湿',
#   '面膜',
#   '16',
#   '片装',
#   '清盈',
#   '保湿',
#   '补水',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '多效',
#   '亮润',
#   '面膜',
#   '16',
#   '片装',
#   '深层',
#   '滋养',
#   '紧致',
#   '肌肤',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '膜法',
#   '补水',
#   '保湿',
#   '修',
#   '36',
#   '片装',
#   ' ',
#   '深层',
#   '补水',
#   '植物',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '补水',
#   '弹润',
#   '面膜',
#   '8',
#   '片装',
#   ' ',
#   '滋润',
#   '补水',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '补水',
#   '嫩肤',
#   '面膜',
#   '组合',
#   '86',
#   '片',
#   ' ',
#   '新品',
#   '补水',
#   '保湿',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '自然',
#   '堂',
#   ' ',
#   '弹嫩',
#   '滋养',
#   '修护',
#   '精华',
#   '油',
#   ' ',
#   '嫩',
#   '滑',
#   '肌肤',
#   ' ',
#   '深入',
#   '滋养'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂净澈',
#   '养护',
#   '卸妆水',
#   ' ',
#   '清洁',
#   '力强',
#   ' ',
#   '保湿',
#   '滋润',
#   '肌肤',
#   '温和'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '明眸',
#   '焕肤',
#   '礼盒',
#   ' ',
#   '凝时',
#   '眼霜',
#   '套装',
#   '滋润',
#   '补水',
#   '去',
#   '眼袋'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '菁',
#   '采',
#   '明眸',
#   '礼盒',
#   ' ',
#   '活泉',
#   '控油',
#   '深层',
#   '清洁',
#   ' ',
#   '快速',
#   '渗透'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂凝时',
#   '焕采',
#   '明眸',
#   '尊享',
#   '礼盒',
#   ' ',
#   '静享',
#   '滋润',
#   ' ',
#   '保湿',
#   '滋润',
#   ' ',
#   '嫩',
#   '滑',
#   '肌肤'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '裸透',
#   '滋养',
#   '礼盒',
#   ' ',
#   '遮',
#   '瑕',
#   '修颜',
#   ' ',
#   '渗透',
#   '补水',
#   ' ',
#   '层层',
#   '滋养'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '自然',
#   '堂',
#   '秋冬',
#   '护手霜',
#   '礼装',
#   '套装',
#   '滋润',
#   '补水',
#   '保湿',
#   '双手',
#   '护手霜'],
#  ['CHANDO', '/', '自然', '堂娇颜', '粉嫩', '保湿', '眼部', '精华', ' ', '四件套', '乳液', '精华'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '精华',
#   '呵护',
#   '套装',
#   ' ',
#   '滋润',
#   '保湿',
#   '秋冬',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '滋润霜',
#   '50g',
#   ' ',
#   '补水',
#   '保湿',
#   ' ',
#   '滋润',
#   '水润',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '乳液',
#   '120ML',
#   ' ',
#   '淡化',
#   '细纹',
#   '补水',
#   '滋润',
#   '专柜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '活泉',
#   '保湿',
#   '修护',
#   '精华',
#   '水',
#   '（',
#   '滋润',
#   '型',
#   '135ml',
#   ' ',
#   '补水',
#   '控油',
#   '爽肤水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '男士',
#   '劲爽',
#   '控油',
#   '洁面膏',
#   ' ',
#   '100g',
#   ' ',
#   '深层',
#   '清洁',
#   ' ',
#   ' ',
#   '男士',
#   '洗面奶'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '滋润霜',
#   '（',
#   '清爽型',
#   '）',
#   '50g',
#   '补水',
#   '保湿',
#   '滋润霜'],
#  ['自然',
#   '堂',
#   ' ',
#   '雪域',
#   '纯粹',
#   '滋润',
#   '洗颜霜',
#   ' ',
#   '110g',
#   ' ',
#   ' ',
#   '补水',
#   '保湿',
#   ' ',
#   ' ',
#   '洗面奶',
#   '女',
#   ' ',
#   '深层',
#   '清洁'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白晶',
#   '采霜',
#   '（',
#   '滋润',
#   '型',
#   '）',
#   '50g',
#   ' ',
#   '滋润',
#   '修护',
#   '面霜',
#   ' ',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '深层',
#   '净化',
#   '控油',
#   '凝露',
#   '60g',
#   ' ',
#   '控油',
#   '补水',
#   '保湿',
#   '滋润',
#   ' ',
#   '活泉',
#   '精华',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '修护',
#   '精华液',
#   '35ml',
#   ' ',
#   '淡化',
#   '细纹',
#   '护肤',
#   '精华'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '活泉',
#   '保湿',
#   '精华',
#   '套装',
#   ' ',
#   '保湿',
#   '补水',
#   '滋润',
#   '控油',
#   '面部',
#   '护理',
#   '套装'],
#  ['自然',
#   '堂',
#   ' ',
#   '水润',
#   '保湿',
#   '柔肤水',
#   ' ',
#   '135ml',
#   ' ',
#   '补水',
#   '保湿',
#   '清透锁',
#   '水',
#   ' ',
#   '专柜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿霜',
#   '50g',
#   ' ',
#   '补水',
#   '保湿',
#   '锁水',
#   '细腻',
#   '清爽',
#   '防',
#   '干燥',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '长效',
#   '保湿霜',
#   '50g',
#   ' ',
#   '深层',
#   '补水',
#   '持久',
#   '锁水',
#   '细腻',
#   '清爽',
#   '滋润'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '男士',
#   '面部',
#   '护肤',
#   '套装',
#   ' ',
#   ' ',
#   '洁面',
#   '洗面奶',
#   '爽肤水',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润',
#   '深澈',
#   '精华',
#   '面膜',
#   '贴',
#   '5',
#   '片',
#   ' ',
#   '补水',
#   '面膜',
#   '护肤品',
#   '专柜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '嫩白',
#   '保湿霜',
#   '50g',
#   ' ',
#   ' ',
#   '保湿',
#   '补水',
#   '滋润',
#   '清',
#   '保湿霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   ' ',
#   '保湿',
#   '乳',
#   '100ML',
#   ' ',
#   '持久',
#   '保湿',
#   '水嫩',
#   '肌肤',
#   '补水',
#   ' ',
#   '乳液'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白水',
#   '乳',
#   '套装',
#   ' ',
#   '爽肤水',
#   '乳液',
#   '面膜',
#   ' ',
#   '亮肤',
#   '补水',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '套装',
#   '水乳',
#   '/',
#   '霜',
#   '套装',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '淡化',
#   '细纹'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '冰肌',
#   '精华',
#   '套组',
#   ' ',
#   '滋润',
#   '护肤',
#   ' ',
#   '精华',
#   '爽肤水',
#   'BB',
#   '套装'],
#  ['自然', '堂水润', '保湿', '洁面', '套装', ' ', '深层', '清洁', '不', '紧绷', '补水', '保湿', '洁面'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿',
#   '面膜',
#   '5',
#   '片装',
#   ' ',
#   '滋润',
#   '补水',
#   '保湿',
#   '面膜',
#   '贴',
#   ' ',
#   '包邮',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '粉嫩',
#   '保湿',
#   '面膜',
#   '面贴膜',
#   '5',
#   '片',
#   ' ',
#   ' ',
#   '密集',
#   '补水',
#   '修护',
#   '面膜',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '密集',
#   '修护',
#   '滋润',
#   '冰肌',
#   '膜',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '面膜'],
#  ['自然',
#   '堂',
#   '男士',
#   '保湿',
#   '补水',
#   '霜',
#   '矿物',
#   '元素',
#   '滋润',
#   '肌肤',
#   '面霜',
#   '护肤品',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '滋润',
#   '乳液',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '修护',
#   '乳液',
#   '护肤'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润',
#   '晶采',
#   '眼霜',
#   '15g',
#   ' ',
#   '淡化',
#   '黑眼圈',
#   '细纹',
#   '紧致',
#   ' ',
#   '眼部',
#   '护理',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '深层',
#   '补水',
#   '露',
#   ' ',
#   '补水',
#   '保湿',
#   ' ',
#   '平衡',
#   '油性',
#   '肌肤',
#   '化妆品',
#   '护肤',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '眼部',
#   '精华',
#   '乳',
#   '18g',
#   '淡化',
#   '细纹',
#   '黑眼圈',
#   '滋润',
#   '眼霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   'BB',
#   '家族',
#   '润泽',
#   '无瑕',
#   '养护',
#   '粉底液',
#   '遮',
#   '瑕',
#   '粉底液',
#   '遮',
#   '瑕',
#   '调整',
#   '肤色'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '水乳',
#   '套装',
#   ' ',
#   '爽肤水',
#   '冰肌',
#   '水',
#   '乳液',
#   '面霜',
#   '护理',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿',
#   '面部',
#   '护理',
#   '套装',
#   ' ',
#   '洗面奶',
#   '爽肤水',
#   '乳液',
#   '面霜',
#   '补水',
#   '女'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '雪润皙',
#   '白',
#   '冰肌',
#   '水送',
#   '面膜',
#   '补水',
#   '保湿',
#   '修护',
#   '爽肤水',
#   '化妆水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '冰肌',
#   '水',
#   '（',
#   '凝润型',
#   '）',
#   '保湿',
#   '补水',
#   '修护',
#   '滋润',
#   ' ',
#   '爽肤水'],
#  ['自然',
#   '堂',
#   ' ',
#   '凝',
#   '时鲜',
#   '颜',
#   '洁面霜',
#   '110g',
#   ' ',
#   '洁面',
#   '保湿',
#   '滋润',
#   '不',
#   '紧绷',
#   ' ',
#   '洗面奶',
#   '专柜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '滋润',
#   '精华液',
#   ' ',
#   '补水',
#   '保湿',
#   '修护',
#   '滋润',
#   '精华液'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '男士',
#   '保湿',
#   '精华',
#   '眼霜',
#   '淡化',
#   '黑眼圈',
#   '细纹',
#   '紧致',
#   '眼部',
#   '护理',
#   '正品'],
#  ['自然',
#   '堂',
#   '男士',
#   '冰川',
#   '控油',
#   '爽肤水',
#   ' ',
#   '补水',
#   '保湿',
#   '控油',
#   '须',
#   '后',
#   '水',
#   '正品',
#   '包邮'],
#  ['自然',
#   '堂',
#   ' ',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '眼霜',
#   '15g',
#   ' ',
#   '淡化',
#   '黑眼圈',
#   '细纹',
#   ' ',
#   '保湿',
#   ' ',
#   '专柜',
#   '正品'],
#  ['自然',
#   '堂',
#   '男士',
#   '控油',
#   '补水',
#   '露',
#   ' ',
#   '补水',
#   '保湿',
#   '控油',
#   '清爽',
#   '男士',
#   '护肤品',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '补水',
#   '控油',
#   '洁面膏',
#   '（',
#   '泡沫',
#   '型',
#   '）',
#   '110g',
#   ' ',
#   ' ',
#   '深层',
#   '清洁',
#   ' ',
#   '正品',
#   ' ',
#   '包邮'],
#  ['自然',
#   '堂',
#   ' ',
#   '雪润',
#   '深澈',
#   '皙',
#   '白',
#   '精华液',
#   '40ml',
#   ' ',
#   '保湿',
#   '滋润',
#   ' ',
#   '美白',
#   '精华',
#   ' ',
#   '面部',
#   '精华',
#   '正品'],
#  ['专柜',
#   '正品',
#   '自然',
#   '堂',
#   ' ',
#   '活泉',
#   '加倍',
#   '保湿霜',
#   '50g',
#   ' ',
#   '补水',
#   '锁水',
#   '减少',
#   '细纹',
#   '滋润',
#   '肌肤'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '控油',
#   '净爽',
#   '泡沫',
#   '洁面膏',
#   '110g',
#   ' ',
#   '控油',
#   '补水',
#   ' ',
#   '包邮',
#   ' ',
#   '洗面奶',
#   '女',
#   '男'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '滋润',
#   '保湿',
#   '精华',
#   '霜',
#   'BB',
#   '霜',
#   '35ml',
#   ' ',
#   '补水',
#   '保湿',
#   '隔离',
#   'BB',
#   '霜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润',
#   '深澈',
#   '皙',
#   '白',
#   '补水',
#   '套装',
#   ' ',
#   '洗面奶',
#   '冰肌',
#   '水',
#   '乳液',
#   '补水',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '冰肌',
#   '滋润',
#   '套装',
#   ' ',
#   '洗面奶',
#   '爽肤水',
#   '乳液',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白',
#   '精华',
#   '套装',
#   ' ',
#   '美白',
#   '保湿',
#   '补水',
#   '滋润',
#   '护理',
#   '爽肤水',
#   '精华'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂凝时',
#   '休眠',
#   '霜',
#   '（',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '霜',
#   '淡化',
#   '细纹',
#   '面霜'],
#  ['自然',
#   '堂',
#   ' ',
#   '专柜',
#   '正品',
#   ' ',
#   '水润',
#   '保湿',
#   '柔肤',
#   '乳',
#   ' ',
#   '清透',
#   '补水',
#   '保湿',
#   '乳液',
#   '清透',
#   '补水',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
#   '嫩白',
#   '保湿',
#   '柔肤水',
#   ' ',
#   '135ml',
#   ' ',
#   '娇颜亮',
#   '润',
#   '升级',
#   ' ',
#   '正品',
#   '包邮',
#   ' ',
#   '保湿',
#   '爽肤水'],
#  ['自然',
#   '堂娇颜',
#   ' ',
#   '保湿',
#   '精华液',
#   ' ',
#   '30ml',
#   ' ',
#   '保湿',
#   '补水',
#   '提亮',
#   '肤色',
#   ' ',
#   '面部',
#   '精华'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '嫩白',
#   '保湿霜',
#   '（',
#   '清爽型',
#   '）',
#   '50g',
#   '玫瑰',
#   '原液',
#   '补水',
#   '保湿',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿',
#   '洗颜霜',
#   '(',
#   '干性',
#   '肌肤',
#   '适用',
#   ')',
#   ' ',
#   '100g',
#   '补水',
#   '保湿',
#   '洗面奶'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿',
#   '洗颜霜',
#   ' ',
#   '专柜',
#   '正品',
#   ' ',
#   '洗面奶',
#   '女',
#   ' ',
#   '深层',
#   '清洁',
#   '不',
#   '紧绷'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '嫩白',
#   '基础',
#   '三件',
#   '套装',
#   '面部',
#   '护理',
#   '套装',
#   ' ',
#   '滋润',
#   '保湿',
#   '补水',
#   '女'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '冰肌',
#   '水',
#   ' ',
#   ' ',
#   '淡化',
#   '细纹',
#   '补水',
#   '保湿',
#   '清爽',
#   '修护',
#   '爽肤水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '冰肌',
#   '水',
#   '清润',
#   '型',
#   ' ',
#   ' ',
#   '补水',
#   '保湿',
#   '修护',
#   '爽肤水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂光',
#   '透',
#   '无瑕',
#   '矿物',
#   '养护',
#   '两用',
#   '粉饼',
#   '保湿',
#   '修护',
#   '遮',
#   '瑕',
#   '定妆',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂果',
#   '漾莹亮',
#   '养护',
#   '唇彩',
#   ' ',
#   '持久',
#   '保湿',
#   '滋润',
#   '唇膏',
#   '口红',
#   '彩'],
#  ['自然',
#   '堂',
#   '男士',
#   '洁面',
#   '2',
#   '支装',
#   ' ',
#   '深层',
#   '清洁',
#   '清爽',
#   '控油',
#   '洗面奶',
#   '男士',
#   '正品'],
#  ['自然', '堂植萃', '净澈', '养护', '眼唇', '卸妆液', '深层', '清洁', '眼部', '唇部', '正品', '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂晶透',
#   '无瑕',
#   '散粉',
#   '蜜粉',
#   '定妆',
#   '粉',
#   ' ',
#   '控油',
#   '保湿',
#   '光泽',
#   '美肌',
#   '彩妆',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '翘密',
#   '.',
#   '纤长',
#   '随心',
#   '控',
#   '睫毛膏',
#   '黑色',
#   ' ',
#   '浓密',
#   '卷',
#   '翘',
#   '持久',
#   '定型',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂亲',
#   '蜜亮',
#   '彩',
#   '唇膏',
#   '笔护唇',
#   ' ',
#   '保湿',
#   '滋养',
#   '多色',
#   '口红',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂植萃',
#   '净澈',
#   '养护',
#   '卸妆乳',
#   ' ',
#   '脸部',
#   '卸妆',
#   '温和',
#   '舒缓',
#   '彩妆',
#   '正品',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '深邃',
#   '精致',
#   '眼线笔',
#   '黑色',
#   ' ',
#   '持久',
#   '不',
#   '黏腻',
#   '眼部',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '粉嫩',
#   '眼霜',
#   '套装',
#   ' ',
#   '水嫩',
#   '肌肤',
#   ' ',
#   '爽肤水',
#   '乳液',
#   '眼霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白晶采',
#   '日霜',
#   '50g',
#   ' ',
#   'SPF15',
#   '/',
#   'PA',
#   '++',
#   ' ',
#   '轻透',
#   '保湿',
#   '滋润',
#   '修护'],
#  ['自然',
#   '堂',
#   ' ',
#   '雪润皙',
#   '白',
#   '密集',
#   '修护',
#   '晚霜',
#   ' ',
#   '50g',
#   ' ',
#   '夜间',
#   '修护',
#   '补水',
#   '加倍',
#   '护理',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '嫩肤',
#   '保湿',
#   '精华',
#   '套装',
#   ' ',
#   '滋润',
#   '保湿',
#   '补水',
#   '面部',
#   '护理',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '保湿',
#   '补水',
#   '滋润',
#   '呵护',
#   '套装',
#   ' ',
#   '护肤品',
#   '套装',
#   '女',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白日',
#   '晚霜',
#   '套装',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '面霜',
#   '套'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '滋润',
#   '礼盒',
#   '15',
#   '周年',
#   '定制',
#   '纪念版',
#   '套装'],
#  ['自然',
#   '堂',
#   '自动',
#   '双头',
#   '易画',
#   '眼线笔',
#   ' ',
#   '帖服',
#   '持久',
#   '不',
#   '晕染',
#   '眼线笔',
#   ' ',
#   '眼部'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '炫彩盈',
#   '润唇膏',
#   ' ',
#   '滋润',
#   '保湿',
#   '持久',
#   '唇膏',
#   '多色',
#   '口红',
#   '女',
#   ' ',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '修护',
#   '眼霜',
#   '15g',
#   ' ',
#   '去',
#   '淡化',
#   '黑眼圈',
#   '眼袋',
#   '细纹'],
#  ['自然',
#   '堂',
#   '雪域',
#   '倍护',
#   '防晒霜',
#   'SPF30',
#   '+',
#   'PA',
#   '+++',
#   '隔离',
#   '保湿',
#   '防晒',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '轻盈',
#   '身体',
#   '防晒乳',
#   '（',
#   '喷雾',
#   '型',
#   '）',
#   'SPF30',
#   '/',
#   'PA',
#   '++',
#   '防晒'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '雪域',
#   '冰肌',
#   '晒',
#   '后',
#   '修护露',
#   ' ',
#   '保湿',
#   '晒',
#   '后',
#   '修护',
#   '清爽',
#   '补水',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润晶',
#   '采裸透',
#   '气垫',
#   '霜',
#   ' ',
#   '保湿',
#   '水润',
#   '贴',
#   '妆',
#   '遮',
#   '瑕',
#   ' ',
#   '气垫',
#   'BB',
#   '霜'],
#  ['自然',
#   '堂亮',
#   '眸',
#   '持久',
#   '眼线',
#   '膏',
#   ' ',
#   ' ',
#   '持久',
#   '防水',
#   '不',
#   '晕染',
#   '速',
#   '干眼',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜淡斑',
#   '精华液',
#   '40ml',
#   '淡化',
#   '干纹',
#   '细纹',
#   '滋润',
#   '精华',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
#   '雪润晶',
#   '采裸透',
#   '气垫',
#   '霜',
#   '（',
#   '替换',
#   '装',
#   '）',
#   '保湿',
#   '修颜水润',
#   '贴',
#   '妆',
#   ' ',
#   '气垫',
#   'BB',
#   '霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '男士',
#   ' ',
#   '控油',
#   '活炭',
#   '抗',
#   '黑头',
#   '洁面膏',
#   ' ',
#   '清洁',
#   '保湿',
#   '控油',
#   ' ',
#   '洗面奶'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '男士',
#   '控油',
#   '柔珠',
#   '深层',
#   '洁面',
#   'ㄠ',
#   ' ',
#   '清爽',
#   '控油',
#   '不',
#   '紧绷',
#   '洗面奶'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润晶',
#   '采裸透',
#   '气垫',
#   '霜',
#   '+',
#   '替换',
#   '装',
#   '保湿',
#   '水润',
#   '贴',
#   '妆',
#   'BB',
#   '霜',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '定制',
#   '礼盒',
#   ' ',
#   '淡化',
#   '细纹',
#   '干纹',
#   ' ',
#   '滋润',
#   '精华',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '保湿',
#   '滋润',
#   ' ',
#   '呵护',
#   '套装',
#   ' ',
#   '补水',
#   '乳霜',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '粉嫩',
#   '保湿',
#   '眼霜',
#   '20g',
#   ' ',
#   '淡化',
#   '黑眼圈',
#   '细纹',
#   ' ',
#   '保湿',
#   '专柜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '粉嫩',
#   '洁肤',
#   '霜',
#   ' ',
#   '100g',
#   '深层',
#   '清洁',
#   '补水',
#   ' ',
#   '洗面奶',
#   '女',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   ' ',
#   '滋润',
#   '补水',
#   '呵护',
#   '臻',
#   '选',
#   '套装',
#   ' ',
#   '淡化',
#   '细纹',
#   '补水',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '彩妆',
#   '护肤',
#   '组合',
#   '套装',
#   ' ',
#   '唇膏',
#   '眼线笔',
#   ' ',
#   '滋润',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '滋润',
#   '滋养',
#   '护唇膏',
#   ' ',
#   '保湿',
#   '滋润',
#   '修护',
#   '干裂',
#   '润唇膏',
#   ' ',
#   '补水',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '护手霜',
#   '3',
#   '支装',
#   '套装',
#   '面膜',
#   ' ',
#   '滋润',
#   '保湿',
#   ' ',
#   '防裂',
#   '修护',
#   '护手霜',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '鲜嫩',
#   '保湿',
#   '护手霜',
#   '50g',
#   '保湿',
#   '补水',
#   ' ',
#   '改善',
#   '干裂',
#   ' ',
#   ' ',
#   '护手霜',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '柔润',
#   '细嫩',
#   '护手霜',
#   '50g',
#   ' ',
#   '滋润',
#   '保湿',
#   '补水',
#   '嫩肤',
#   ' ',
#   '护手霜',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '冰肌',
#   '水',
#   '（',
#   '滋润',
#   '型',
#   '）',
#   '淡化',
#   '细纹',
#   '补水',
#   '滋润',
#   '爽肤水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '立体',
#   '塑形',
#   '双头',
#   '眉笔',
#   ' ',
#   '修饰',
#   '眉部',
#   '轮廓',
#   '调整',
#   '眉形',
#   '彩妆',
#   '女',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂凝时',
#   '肌活',
#   '修纹',
#   '精华',
#   '霜',
#   'SPF30',
#   '++',
#   '修纹',
#   '遮',
#   '瑕',
#   '补水',
#   '保湿',
#   'BB',
#   '霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '抗皱',
#   '精华液',
#   '40ml',
#   ' ',
#   '小',
#   'V',
#   '脸',
#   '提升',
#   '轮廓',
#   '淡化',
#   '皱纹'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '抗皱',
#   '滋养',
#   '乳液',
#   '120ml',
#   ' ',
#   '滋润',
#   '保湿',
#   '肌肤',
#   '弹性',
#   '轮廓'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '抗皱',
#   '气色',
#   '液',
#   '160ml',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '爽肤水',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '抗皱',
#   '滋养',
#   '早安',
#   '霜',
#   '50g',
#   ' ',
#   '日间',
#   '防护',
#   '肌肤',
#   '弹性',
#   '滋润'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润',
#   '深澈洁',
#   '面膏',
#   ' ',
#   '110g',
#   ' ',
#   '深层',
#   '清洁',
#   '不',
#   '紧绷',
#   ' ',
#   '洗面奶',
#   '女'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '多重',
#   '隔离',
#   '防晒乳',
#   'SPF30',
#   '+',
#   '/',
#   'PA',
#   '++',
#   '隔离',
#   '保湿',
#   '自然',
#   '堂',
#   '防晒霜',
#   '女'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '多重',
#   '隔离',
#   '防晒乳',
#   'SPF20',
#   '/',
#   'PA',
#   '++',
#   ' ',
#   '隔离',
#   ' ',
#   '保湿',
#   '防晒霜',
#   '女',
#   '男'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白晶',
#   '采乳',
#   '120ML',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '乳液',
#   ' ',
#   '专柜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '亲蜜',
#   '莹润',
#   '柔彩',
#   '唇膏',
#   '笔',
#   '2.5',
#   'g',
#   ' ',
#   '水感',
#   '亮泽',
#   ' ',
#   '柔滑',
#   '不',
#   '粘腻'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '滋润',
#   '补水',
#   '礼盒',
#   '套装',
#   ' ',
#   '洗面奶',
#   '爽肤水',
#   '乳液',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白',
#   '多重',
#   '防晒',
#   '隔离霜',
#   ' ',
#   'SPF30',
#   '+',
#   '/',
#   'PA',
#   '+++',
#   ' ',
#   '滋润',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '补水',
#   '嫩肤',
#   '面膜',
#   '组合',
#   '21',
#   '片',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '净透',
#   '冰肌',
#   '角质',
#   '调理',
#   '凝露',
#   ' ',
#   '去除',
#   '老废',
#   '角质'],
#  ['自然',
#   '堂轻透',
#   '无瑕',
#   '修颜霜',
#   'SPF25',
#   ' ',
#   'PA',
#   '++',
#   ' ',
#   '多效',
#   'BB',
#   ' ',
#   '防晒',
#   '隔离',
#   '均匀',
#   '肤色'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂轻透',
#   '无瑕',
#   '修颜霜',
#   'SPF20',
#   ' ',
#   'PA',
#   '++',
#   '（',
#   '润白亮',
#   '采',
#   '）',
#   'BB',
#   '霜',
#   '修颜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '水润',
#   '套装',
#   ' ',
#   '补水',
#   '紧致',
#   '滋养',
#   '深层',
#   '滋养',
#   '修护',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   'V',
#   '脸',
#   '滋养',
#   '套装',
#   ' ',
#   '紧致',
#   '肌肤',
#   '洗面奶',
#   '+',
#   '乳液',
#   '爽肤水',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '雪莲',
#   '舒缓',
#   '保湿',
#   '面膜',
#   '5',
#   '片装',
#   ' ',
#   '舒缓',
#   '水润',
#   '呵护',
#   '肌肤'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '雪域',
#   '紫草',
#   '细致',
#   '毛孔',
#   '亮润',
#   '面膜',
#   '8',
#   '片装',
#   ' ',
#   '补水',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '雪域',
#   '补水',
#   '保湿',
#   '面膜',
#   '26',
#   '片',
#   '平衡',
#   '油脂',
#   '细致',
#   '毛孔'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '雪莲',
#   '舒缓',
#   '多效',
#   '保湿',
#   '面膜',
#   '16',
#   '片',
#   ' ',
#   '肌肤',
#   '水润',
#   '舒适'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '雪域',
#   '龙胆',
#   '亮润',
#   '面膜',
#   '5',
#   '片装',
#   ' ',
#   '提亮',
#   '肤色',
#   '水润',
#   '透亮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '多效',
#   '补水',
#   '保湿',
#   '面膜',
#   '16',
#   '片装',
#   '清盈',
#   '保湿',
#   '补水',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '多效',
#   '亮润',
#   '面膜',
#   '16',
#   '片装',
#   '深层',
#   '滋养',
#   '紧致',
#   '肌肤',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '膜法',
#   '补水',
#   '保湿',
#   '修',
#   '36',
#   '片装',
#   ' ',
#   '深层',
#   '补水',
#   '植物',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '补水',
#   '弹润',
#   '面膜',
#   '8',
#   '片装',
#   ' ',
#   '滋润',
#   '补水',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '补水',
#   '嫩肤',
#   '面膜',
#   '组合',
#   '86',
#   '片',
#   ' ',
#   '新品',
#   '补水',
#   '保湿',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '自然',
#   '堂',
#   ' ',
#   '弹嫩',
#   '滋养',
#   '修护',
#   '精华',
#   '油',
#   ' ',
#   '嫩',
#   '滑',
#   '肌肤',
#   ' ',
#   '深入',
#   '滋养'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂净澈',
#   '养护',
#   '卸妆水',
#   ' ',
#   '清洁',
#   '力强',
#   ' ',
#   '保湿',
#   '滋润',
#   '肌肤',
#   '温和'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '明眸',
#   '焕肤',
#   '礼盒',
#   ' ',
#   '凝时',
#   '眼霜',
#   '套装',
#   '滋润',
#   '补水',
#   '去',
#   '眼袋'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '菁',
#   '采',
#   '明眸',
#   '礼盒',
#   ' ',
#   '活泉',
#   '控油',
#   '深层',
#   '清洁',
#   ' ',
#   '快速',
#   '渗透'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂凝时',
#   '焕采',
#   '明眸',
#   '尊享',
#   '礼盒',
#   ' ',
#   '静享',
#   '滋润',
#   ' ',
#   '保湿',
#   '滋润',
#   ' ',
#   '嫩',
#   '滑',
#   '肌肤'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '裸透',
#   '滋养',
#   '礼盒',
#   ' ',
#   '遮',
#   '瑕',
#   '修颜',
#   ' ',
#   '渗透',
#   '补水',
#   ' ',
#   '层层',
#   '滋养'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '自然',
#   '堂',
#   '秋冬',
#   '护手霜',
#   '礼装',
#   '套装',
#   '滋润',
#   '补水',
#   '保湿',
#   '双手',
#   '护手霜'],
#  ['CHANDO', '/', '自然', '堂娇颜', '粉嫩', '保湿', '眼部', '精华', ' ', '四件套', '乳液', '精华'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '精华',
#   '呵护',
#   '套装',
#   ' ',
#   '滋润',
#   '保湿',
#   '秋冬',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '滋润霜',
#   '50g',
#   ' ',
#   '补水',
#   '保湿',
#   ' ',
#   '滋润',
#   '水润',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '乳液',
#   '120ML',
#   ' ',
#   '淡化',
#   '细纹',
#   '补水',
#   '滋润',
#   '专柜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '男士',
#   '劲爽',
#   '控油',
#   '洁面膏',
#   ' ',
#   '100g',
#   ' ',
#   '深层',
#   '清洁',
#   ' ',
#   ' ',
#   '男士',
#   '洗面奶'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '滋润霜',
#   '（',
#   '清爽型',
#   '）',
#   '50g',
#   '补水',
#   '保湿',
#   '滋润霜'],
#  ['自然',
#   '堂',
#   ' ',
#   '雪域',
#   '纯粹',
#   '滋润',
#   '洗颜霜',
#   ' ',
#   '110g',
#   ' ',
#   ' ',
#   '补水',
#   '保湿',
#   ' ',
#   ' ',
#   '洗面奶',
#   '女',
#   ' ',
#   '深层',
#   '清洁'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白晶',
#   '采霜',
#   '（',
#   '滋润',
#   '型',
#   '）',
#   '50g',
#   ' ',
#   '滋润',
#   '修护',
#   '面霜',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '修护',
#   '精华液',
#   '35ml',
#   ' ',
#   '淡化',
#   '细纹',
#   '护肤',
#   '精华'],
#  ['自然',
#   '堂',
#   ' ',
#   '水润',
#   '保湿',
#   '柔肤水',
#   ' ',
#   '135ml',
#   ' ',
#   '补水',
#   '保湿',
#   '清透锁',
#   '水',
#   ' ',
#   '专柜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿霜',
#   '50g',
#   ' ',
#   '补水',
#   '保湿',
#   '锁水',
#   '细腻',
#   '清爽',
#   '防',
#   '干燥',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '长效',
#   '保湿霜',
#   '50g',
#   ' ',
#   '深层',
#   '补水',
#   '持久',
#   '锁水',
#   '细腻',
#   '清爽',
#   '滋润'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '男士',
#   '面部',
#   '护肤',
#   '套装',
#   ' ',
#   ' ',
#   '洁面',
#   '洗面奶',
#   '爽肤水',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '嫩白',
#   '保湿霜',
#   '50g',
#   ' ',
#   ' ',
#   '保湿',
#   '补水',
#   '滋润',
#   '清',
#   '保湿霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   ' ',
#   '保湿',
#   '乳',
#   '100ML',
#   ' ',
#   '持久',
#   '保湿',
#   '水嫩',
#   '肌肤',
#   '补水',
#   ' ',
#   '乳液'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白水',
#   '乳',
#   '套装',
#   ' ',
#   '爽肤水',
#   '乳液',
#   '面膜',
#   ' ',
#   '亮肤',
#   '补水',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '套装',
#   '水乳',
#   '/',
#   '霜',
#   '套装',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '淡化',
#   '细纹'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '冰肌',
#   '精华',
#   '套组',
#   ' ',
#   '滋润',
#   '护肤',
#   ' ',
#   '精华',
#   '爽肤水',
#   'BB',
#   '套装'],
#  ['自然', '堂水润', '保湿', '洁面', '套装', ' ', '深层', '清洁', '不', '紧绷', '补水', '保湿', '洁面'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '滋润',
#   '乳液',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '修护',
#   '乳液',
#   '护肤'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润',
#   '晶采',
#   '眼霜',
#   '15g',
#   ' ',
#   '淡化',
#   '黑眼圈',
#   '细纹',
#   '紧致',
#   ' ',
#   '眼部',
#   '护理',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '眼部',
#   '精华',
#   '乳',
#   '18g',
#   '淡化',
#   '细纹',
#   '黑眼圈',
#   '滋润',
#   '眼霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '水乳',
#   '套装',
#   ' ',
#   '爽肤水',
#   '冰肌',
#   '水',
#   '乳液',
#   '面霜',
#   '护理',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿',
#   '面部',
#   '护理',
#   '套装',
#   ' ',
#   '洗面奶',
#   '爽肤水',
#   '乳液',
#   '面霜',
#   '补水',
#   '女'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '雪润皙',
#   '白',
#   '冰肌',
#   '水送',
#   '面膜',
#   '补水',
#   '保湿',
#   '修护',
#   '爽肤水',
#   '化妆水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '冰肌',
#   '水',
#   '（',
#   '凝润型',
#   '）',
#   '保湿',
#   '补水',
#   '修护',
#   '滋润',
#   ' ',
#   '爽肤水'],
#  ['自然',
#   '堂',
#   ' ',
#   '凝',
#   '时鲜',
#   '颜',
#   '洁面霜',
#   '110g',
#   ' ',
#   '洁面',
#   '保湿',
#   '滋润',
#   '不',
#   '紧绷',
#   ' ',
#   '洗面奶',
#   '专柜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '滋润',
#   '精华液',
#   ' ',
#   '补水',
#   '保湿',
#   '修护',
#   '滋润',
#   '精华液'],
#  ['自然',
#   '堂',
#   ' ',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '眼霜',
#   '15g',
#   ' ',
#   '淡化',
#   '黑眼圈',
#   '细纹',
#   ' ',
#   '保湿',
#   ' ',
#   '专柜',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
#   '雪润',
#   '深澈',
#   '皙',
#   '白',
#   '精华液',
#   '40ml',
#   ' ',
#   '保湿',
#   '滋润',
#   ' ',
#   '美白',
#   '精华',
#   ' ',
#   '面部',
#   '精华',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润',
#   '深澈',
#   '皙',
#   '白',
#   '补水',
#   '套装',
#   ' ',
#   '洗面奶',
#   '冰肌',
#   '水',
#   '乳液',
#   '补水',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '冰肌',
#   '滋润',
#   '套装',
#   ' ',
#   '洗面奶',
#   '爽肤水',
#   '乳液',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白',
#   '精华',
#   '套装',
#   ' ',
#   '美白',
#   '保湿',
#   '补水',
#   '滋润',
#   '护理',
#   '爽肤水',
#   '精华'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂凝时',
#   '休眠',
#   '霜',
#   '（',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '霜',
#   '淡化',
#   '细纹',
#   '面霜'],
#  ['自然',
#   '堂',
#   ' ',
#   '专柜',
#   '正品',
#   ' ',
#   '水润',
#   '保湿',
#   '柔肤',
#   '乳',
#   ' ',
#   '清透',
#   '补水',
#   '保湿',
#   '乳液',
#   '清透',
#   '补水',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
#   '嫩白',
#   '保湿',
#   '柔肤水',
#   ' ',
#   '135ml',
#   ' ',
#   '娇颜亮',
#   '润',
#   '升级',
#   ' ',
#   '正品',
#   '包邮',
#   ' ',
#   '保湿',
#   '爽肤水'],
#  ['自然',
#   '堂娇颜',
#   ' ',
#   '保湿',
#   '精华液',
#   ' ',
#   '30ml',
#   ' ',
#   '保湿',
#   '补水',
#   '提亮',
#   '肤色',
#   ' ',
#   '面部',
#   '精华'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '嫩白',
#   '保湿霜',
#   '（',
#   '清爽型',
#   '）',
#   '50g',
#   '玫瑰',
#   '原液',
#   '补水',
#   '保湿',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿',
#   '洗颜霜',
#   '(',
#   '干性',
#   '肌肤',
#   '适用',
#   ')',
#   ' ',
#   '100g',
#   '补水',
#   '保湿',
#   '洗面奶'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿',
#   '洗颜霜',
#   ' ',
#   '专柜',
#   '正品',
#   ' ',
#   '洗面奶',
#   '女',
#   ' ',
#   '深层',
#   '清洁',
#   '不',
#   '紧绷'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '嫩白',
#   '基础',
#   '三件',
#   '套装',
#   '面部',
#   '护理',
#   '套装',
#   ' ',
#   '滋润',
#   '保湿',
#   '补水',
#   '女'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '冰肌',
#   '水',
#   ' ',
#   ' ',
#   '淡化',
#   '细纹',
#   '补水',
#   '保湿',
#   '清爽',
#   '修护',
#   '爽肤水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '冰肌',
#   '水',
#   '清润',
#   '型',
#   ' ',
#   ' ',
#   '补水',
#   '保湿',
#   '修护',
#   '爽肤水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂果',
#   '漾莹亮',
#   '养护',
#   '唇彩',
#   ' ',
#   '持久',
#   '保湿',
#   '滋润',
#   '唇膏',
#   '口红',
#   '彩'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '粉嫩',
#   '眼霜',
#   '套装',
#   ' ',
#   '水嫩',
#   '肌肤',
#   ' ',
#   '爽肤水',
#   '乳液',
#   '眼霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白晶采',
#   '日霜',
#   '50g',
#   ' ',
#   'SPF15',
#   '/',
#   'PA',
#   '++',
#   ' ',
#   '轻透',
#   '保湿',
#   '滋润',
#   '修护'],
#  ['自然',
#   '堂',
#   ' ',
#   '雪润皙',
#   '白',
#   '密集',
#   '修护',
#   '晚霜',
#   ' ',
#   '50g',
#   ' ',
#   '夜间',
#   '修护',
#   '补水',
#   '加倍',
#   '护理',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '保湿',
#   '补水',
#   '滋润',
#   '呵护',
#   '套装',
#   ' ',
#   '护肤品',
#   '套装',
#   '女',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白日',
#   '晚霜',
#   '套装',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '面霜',
#   '套'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '修护',
#   '眼霜',
#   '15g',
#   ' ',
#   '去',
#   '淡化',
#   '黑眼圈',
#   '眼袋',
#   '细纹'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润晶',
#   '采裸透',
#   '气垫',
#   '霜',
#   ' ',
#   '保湿',
#   '水润',
#   '贴',
#   '妆',
#   '遮',
#   '瑕',
#   ' ',
#   '气垫',
#   'BB',
#   '霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜淡斑',
#   '精华液',
#   '40ml',
#   '淡化',
#   '干纹',
#   '细纹',
#   '滋润',
#   '精华',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
#   '雪润晶',
#   '采裸透',
#   '气垫',
#   '霜',
#   '（',
#   '替换',
#   '装',
#   '）',
#   '保湿',
#   '修颜水润',
#   '贴',
#   '妆',
#   ' ',
#   '气垫',
#   'BB',
#   '霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '男士',
#   ' ',
#   '控油',
#   '活炭',
#   '抗',
#   '黑头',
#   '洁面膏',
#   ' ',
#   '清洁',
#   '保湿',
#   '控油',
#   ' ',
#   '洗面奶'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '男士',
#   '控油',
#   '柔珠',
#   '深层',
#   '洁面',
#   'ㄠ',
#   ' ',
#   '清爽',
#   '控油',
#   '不',
#   '紧绷',
#   '洗面奶'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '定制',
#   '礼盒',
#   ' ',
#   '淡化',
#   '细纹',
#   '干纹',
#   ' ',
#   '滋润',
#   '精华',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '保湿',
#   '滋润',
#   ' ',
#   '呵护',
#   '套装',
#   ' ',
#   '补水',
#   '乳霜',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '粉嫩',
#   '保湿',
#   '眼霜',
#   '20g',
#   ' ',
#   '淡化',
#   '黑眼圈',
#   '细纹',
#   ' ',
#   '保湿',
#   '专柜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '粉嫩',
#   '洁肤',
#   '霜',
#   ' ',
#   '100g',
#   '深层',
#   '清洁',
#   '补水',
#   ' ',
#   '洗面奶',
#   '女',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   ' ',
#   '滋润',
#   '补水',
#   '呵护',
#   '臻',
#   '选',
#   '套装',
#   ' ',
#   '淡化',
#   '细纹',
#   '补水',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '滋润',
#   '滋养',
#   '护唇膏',
#   ' ',
#   '保湿',
#   '滋润',
#   '修护',
#   '干裂',
#   '润唇膏',
#   ' ',
#   '补水',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '鲜嫩',
#   '保湿',
#   '护手霜',
#   '50g',
#   '保湿',
#   '补水',
#   ' ',
#   '改善',
#   '干裂',
#   ' ',
#   ' ',
#   '护手霜',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '柔润',
#   '细嫩',
#   '护手霜',
#   '50g',
#   ' ',
#   '滋润',
#   '保湿',
#   '补水',
#   '嫩肤',
#   ' ',
#   '护手霜',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '冰肌',
#   '水',
#   '（',
#   '滋润',
#   '型',
#   '）',
#   '淡化',
#   '细纹',
#   '补水',
#   '滋润',
#   '爽肤水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '抗皱',
#   '精华液',
#   '40ml',
#   ' ',
#   '小',
#   'V',
#   '脸',
#   '提升',
#   '轮廓',
#   '淡化',
#   '皱纹'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '抗皱',
#   '滋养',
#   '乳液',
#   '120ml',
#   ' ',
#   '滋润',
#   '保湿',
#   '肌肤',
#   '弹性',
#   '轮廓'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '抗皱',
#   '气色',
#   '液',
#   '160ml',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '爽肤水',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '抗皱',
#   '滋养',
#   '早安',
#   '霜',
#   '50g',
#   ' ',
#   '日间',
#   '防护',
#   '肌肤',
#   '弹性',
#   '滋润'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润',
#   '深澈洁',
#   '面膏',
#   ' ',
#   '110g',
#   ' ',
#   '深层',
#   '清洁',
#   '不',
#   '紧绷',
#   ' ',
#   '洗面奶',
#   '女'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白晶',
#   '采乳',
#   '120ML',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '乳液',
#   ' ',
#   '专柜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白',
#   '多重',
#   '防晒',
#   '隔离霜',
#   ' ',
#   'SPF30',
#   '+',
#   '/',
#   'PA',
#   '+++',
#   ' ',
#   '滋润',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '补水',
#   '嫩肤',
#   '面膜',
#   '组合',
#   '21',
#   '片',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '净透',
#   '冰肌',
#   '角质',
#   '调理',
#   '凝露',
#   ' ',
#   '去除',
#   '老废',
#   '角质'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂轻透',
#   '无瑕',
#   '修颜霜',
#   'SPF20',
#   ' ',
#   'PA',
#   '++',
#   '（',
#   '润白亮',
#   '采',
#   '）',
#   'BB',
#   '霜',
#   '修颜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '雪莲',
#   '舒缓',
#   '保湿',
#   '面膜',
#   '5',
#   '片装',
#   ' ',
#   '舒缓',
#   '水润',
#   '呵护',
#   '肌肤'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '雪域',
#   '补水',
#   '保湿',
#   '面膜',
#   '26',
#   '片',
#   '平衡',
#   '油脂',
#   '细致',
#   '毛孔'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '雪莲',
#   '舒缓',
#   '多效',
#   '保湿',
#   '面膜',
#   '16',
#   '片',
#   ' ',
#   '肌肤',
#   '水润',
#   '舒适'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '雪域',
#   '龙胆',
#   '亮润',
#   '面膜',
#   '5',
#   '片装',
#   ' ',
#   '提亮',
#   '肤色',
#   '水润',
#   '透亮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '多效',
#   '补水',
#   '保湿',
#   '面膜',
#   '16',
#   '片装',
#   '清盈',
#   '保湿',
#   '补水',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '多效',
#   '亮润',
#   '面膜',
#   '16',
#   '片装',
#   '深层',
#   '滋养',
#   '紧致',
#   '肌肤',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '补水',
#   '弹润',
#   '面膜',
#   '8',
#   '片装',
#   ' ',
#   '滋润',
#   '补水',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '补水',
#   '嫩肤',
#   '面膜',
#   '组合',
#   '86',
#   '片',
#   ' ',
#   '新品',
#   '补水',
#   '保湿',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '自然',
#   '堂',
#   ' ',
#   '弹嫩',
#   '滋养',
#   '修护',
#   '精华',
#   '油',
#   ' ',
#   '嫩',
#   '滑',
#   '肌肤',
#   ' ',
#   '深入',
#   '滋养'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '裸透',
#   '滋养',
#   '礼盒',
#   ' ',
#   '遮',
#   '瑕',
#   '修颜',
#   ' ',
#   '渗透',
#   '补水',
#   ' ',
#   '层层',
#   '滋养'],
#  ['CHANDO', '/', '自然', '堂娇颜', '粉嫩', '保湿', '眼部', '精华', ' ', '四件套', '乳液', '精华'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '活泉',
#   '保湿',
#   '修护',
#   '精华',
#   '水',
#   '（',
#   '滋润',
#   '型',
#   '135ml',
#   ' ',
#   '补水',
#   '控油',
#   '爽肤水'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '深层',
#   '净化',
#   '控油',
#   '凝露',
#   '60g',
#   ' ',
#   '控油',
#   '补水',
#   '保湿',
#   '滋润',
#   ' ',
#   '活泉',
#   '精华',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '活泉',
#   '深层',
#   '补水',
#   '酣睡',
#   '膜',
#   ' ',
#   ' ',
#   '补水',
#   '保湿',
#   '免洗',
#   '面膜',
#   ' ',
#   '正品',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '活泉',
#   '保湿',
#   '精华',
#   '套装',
#   ' ',
#   '保湿',
#   '补水',
#   '滋润',
#   '控油',
#   '面部',
#   '护理',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '男士',
#   '面部',
#   '护肤',
#   '套装',
#   ' ',
#   ' ',
#   '洁面',
#   '洗面奶',
#   '爽肤水',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润',
#   '深澈',
#   '精华',
#   '面膜',
#   '贴',
#   '5',
#   '片',
#   ' ',
#   '补水',
#   '面膜',
#   '护肤品',
#   '专柜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白水',
#   '乳',
#   '套装',
#   ' ',
#   '爽肤水',
#   '乳液',
#   '面膜',
#   ' ',
#   '亮肤',
#   '补水',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '套装',
#   '水乳',
#   '/',
#   '霜',
#   '套装',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '淡化',
#   '细纹'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '冰肌',
#   '精华',
#   '套组',
#   ' ',
#   '滋润',
#   '护肤',
#   ' ',
#   '精华',
#   '爽肤水',
#   'BB',
#   '套装'],
#  ['自然', '堂水润', '保湿', '洁面', '套装', ' ', '深层', '清洁', '不', '紧绷', '补水', '保湿', '洁面'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿',
#   '面膜',
#   '5',
#   '片装',
#   ' ',
#   '滋润',
#   '补水',
#   '保湿',
#   '面膜',
#   '贴',
#   ' ',
#   '包邮',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '粉嫩',
#   '保湿',
#   '面膜',
#   '面贴膜',
#   '5',
#   '片',
#   ' ',
#   ' ',
#   '密集',
#   '补水',
#   '修护',
#   '面膜',
#   '包邮'],
#  ['自然',
#   '堂',
#   '男士',
#   '保湿',
#   '补水',
#   '霜',
#   '矿物',
#   '元素',
#   '滋润',
#   '肌肤',
#   '面霜',
#   '护肤品',
#   ' ',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
# ...
#   '气垫',
#   '霜',
#   '+',
#   '替换',
#   '装',
#   '保湿',
#   '水润',
#   '贴',
#   '妆',
#   'BB',
#   '霜',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '雪润',
#   '深澈',
#   '皙',
#   '白',
#   '精华液',
#   '套装',
#   ' ',
#   '保湿',
#   '滋润',
#   '面部',
#   '精华'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '保湿',
#   '滋润',
#   ' ',
#   '呵护',
#   '套装',
#   ' ',
#   '补水',
#   '乳霜',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   ' ',
#   '滋润',
#   '补水',
#   '呵护',
#   '臻',
#   '选',
#   '套装',
#   ' ',
#   '淡化',
#   '细纹',
#   '补水',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '雪润',
#   '净澈',
#   '无瑕',
#   '透白',
#   '套装',
#   ' ',
#   '洗面奶',
#   '爽肤水',
#   'BB',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '活泉',
#   '润养',
#   '无瑕',
#   '超值',
#   '套装',
#   ' ',
#   '控油',
#   '补水',
#   '保湿',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '护手霜',
#   '3',
#   '支装',
#   '套装',
#   '面膜',
#   ' ',
#   '滋润',
#   '保湿',
#   ' ',
#   '防裂',
#   '修护',
#   '护手霜',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '立体',
#   '塑形',
#   '双头',
#   '眉笔',
#   ' ',
#   '修饰',
#   '眉部',
#   '轮廓',
#   '调整',
#   '眉形',
#   '彩妆',
#   '女',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂凝时',
#   '肌活',
#   '修纹',
#   '精华',
#   '霜',
#   'SPF30',
#   '++',
#   '修纹',
#   '遮',
#   '瑕',
#   '补水',
#   '保湿',
#   'BB',
#   '霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '多重',
#   '隔离',
#   '防晒乳',
#   'SPF30',
#   '+',
#   '/',
#   'PA',
#   '++',
#   '隔离',
#   '保湿',
#   '自然',
#   '堂',
#   '防晒霜',
#   '女'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '多重',
#   '隔离',
#   '防晒乳',
#   'SPF20',
#   '/',
#   'PA',
#   '++',
#   ' ',
#   '隔离',
#   ' ',
#   '保湿',
#   '防晒霜',
#   '女',
#   '男'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '亲蜜',
#   '莹润',
#   '柔彩',
#   '唇膏',
#   '笔',
#   '2.5',
#   'g',
#   ' ',
#   '水感',
#   '亮泽',
#   ' ',
#   '柔滑',
#   '不',
#   '粘腻'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '滋润',
#   '补水',
#   '礼盒',
#   '套装',
#   ' ',
#   '洗面奶',
#   '爽肤水',
#   '乳液',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白',
#   '多重',
#   '防晒',
#   '隔离霜',
#   ' ',
#   'SPF30',
#   '+',
#   '/',
#   'PA',
#   '+++',
#   ' ',
#   '滋润',
#   '保湿'],
#  ['自然',
#   '堂轻透',
#   '无瑕',
#   '修颜霜',
#   'SPF25',
#   ' ',
#   'PA',
#   '++',
#   ' ',
#   '多效',
#   'BB',
#   ' ',
#   '防晒',
#   '隔离',
#   '均匀',
#   '肤色'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂轻透',
#   '无瑕',
#   '修颜霜',
#   'SPF20',
#   ' ',
#   'PA',
#   '++',
#   '（',
#   '润白亮',
#   '采',
#   '）',
#   'BB',
#   '霜',
#   '修颜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '水润',
#   '套装',
#   ' ',
#   '补水',
#   '紧致',
#   '滋养',
#   '深层',
#   '滋养',
#   '修护',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   'V',
#   '脸',
#   '滋养',
#   '套装',
#   ' ',
#   '紧致',
#   '肌肤',
#   '洗面奶',
#   '+',
#   '乳液',
#   '爽肤水',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '雪域',
#   '紫草',
#   '细致',
#   '毛孔',
#   '亮润',
#   '面膜',
#   '8',
#   '片装',
#   ' ',
#   '补水',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '雪域',
#   '补水',
#   '保湿',
#   '面膜',
#   '26',
#   '片',
#   '平衡',
#   '油脂',
#   '细致',
#   '毛孔'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '多效',
#   '补水',
#   '保湿',
#   '面膜',
#   '16',
#   '片装',
#   '清盈',
#   '保湿',
#   '补'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '喜马拉雅',
#   '膜法',
#   '补水',
#   '保湿',
#   '修',
#   '36',
#   '片装',
#   ' ',
#   '深层',
#   '补水',
#   '植物',
#   '面膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '甜蜜',
#   '三',
#   '色',
#   '渐变',
#   '咬',
#   '唇膏',
#   ' ',
#   '滋润',
#   '保湿',
#   ' ',
#   '淡化',
#   '唇纹',
#   ' ',
#   '四色',
#   '可',
#   '选'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂净澈',
#   '养护',
#   '卸妆水',
#   ' ',
#   '清洁',
#   '力强',
#   ' ',
#   '保湿',
#   '滋润',
#   '肌肤',
#   '温和'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '雪润晶',
#   '采裸透',
#   '气垫',
#   '霜',
#   '+',
#   '替换',
#   '装',
#   ' ',
#   '保湿',
#   '滋润',
#   'BB',
#   '霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '弹嫩',
#   '紧致',
#   '精华',
#   '眼霜',
#   '套装',
#   ' ',
#   '面部',
#   '精华',
#   '眼霜',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '雪域',
#   ' ',
#   '秋冬',
#   '保湿',
#   '滋润',
#   ' ',
#   '呵护',
#   '套装',
#   ' ',
#   '爽肤水',
#   '乳液'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '喜马拉雅',
#   '补水',
#   '面膜',
#   '21',
#   '片',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '面贴膜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '菁',
#   '采',
#   '明眸',
#   '礼盒',
#   ' ',
#   '活泉',
#   '控油',
#   '深层',
#   '清洁',
#   ' ',
#   '快速',
#   '渗透'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂凝时',
#   '焕采',
#   '明眸',
#   '尊享',
#   '礼盒',
#   ' ',
#   '静享',
#   '滋润',
#   ' ',
#   '保湿',
#   '滋润',
#   ' ',
#   '嫩',
#   '滑',
#   '肌肤'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   ' ',
#   '纯粹',
#   '滋润',
#   '洗颜霜',
#   ' ',
#   '深层',
#   '清洁',
#   ' ',
#   '保湿',
#   '去',
#   '油'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂净',
#   '透',
#   '冰肌',
#   '角质',
#   '调理',
#   '凝露',
#   ' ',
#   '深层',
#   '清洁',
#   ' ',
#   '去角质',
#   ' ',
#   '洗',
#   '出',
#   '污垢'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   ' ',
#   '纯粹',
#   '滋润',
#   '冰肌',
#   '水',
#   '套装',
#   ' ',
#   '保湿',
#   '补水',
#   '修护'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '滋润',
#   '乳液',
#   '礼装',
#   '组合',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '眼霜',
#   '套装',
#   ' ',
#   ' ',
#   '淡化',
#   '黑眼圈',
#   '细纹'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '纯粹',
#   '滋润',
#   '精华液',
#   '套装',
#   ' ',
#   '补水',
#   '保湿',
#   '修护',
#   '滋润',
#   '精华液'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '长效',
#   '保湿霜',
#   '面膜',
#   '套装',
#   ' ',
#   '深层',
#   '补水',
#   '锁水',
#   '细腻',
#   '清爽'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白',
#   '冰肌',
#   '水礼',
#   '装',
#   ' ',
#   ' ',
#   '深入',
#   '补水',
#   ' ',
#   '通透',
#   '肌肤',
#   '匀润',
#   '亮泽'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润',
#   '深澈洁',
#   '面膏',
#   '洗面奶',
#   ' ',
#   '深层',
#   '清洁',
#   ' ',
#   '洗后',
#   '不',
#   '紧绷',
#   ' ',
#   '舒缓'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白晶',
#   '采霜',
#   '/',
#   '日霜',
#   '礼装',
#   ' ',
#   '滋润',
#   '水润',
#   '呵护',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '乳液',
#   '/',
#   '霜',
#   ' ',
#   '凝时',
#   '肌活',
#   '霜',
#   '保湿',
#   '滋润',
#   '秋冬',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '淡斑',
#   '精华液',
#   '淡化',
#   '干纹',
#   '细纹',
#   '滋润',
#   '精华',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '修护',
#   '眼霜',
#   '淡化',
#   '去',
#   '黑眼圈',
#   '眼袋',
#   '滋润',
#   '细纹'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '抗皱',
#   '气色',
#   '液',
#   ' ',
#   '深入',
#   '补水',
#   ' ',
#   '爽肤水',
#   ' ',
#   '细化',
#   '毛孔'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '弹嫩',
#   '细致',
#   '洁颜霜礼装',
#   '套装',
#   ' ',
#   '洗面奶',
#   '温和',
#   '不',
#   '紧绷'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '抗皱',
#   '精华液',
#   '塑形',
#   '肌肤',
#   ' ',
#   '小',
#   'V',
#   '脸',
#   '套装',
#   '紧致',
#   '弹嫩'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂弹',
#   '嫩',
#   '紧致',
#   '抗皱',
#   '眼霜',
#   ' ',
#   '紧致',
#   '去',
#   '黑眼圈',
#   '去',
#   '眼袋',
#   '去',
#   '脂肪粒',
#   '眼霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '冰肌',
#   '莹润',
#   '焕颜',
#   '隔离霜',
#   ' ',
#   '裸妆',
#   '隔离',
#   '控油',
#   '保湿',
#   '遮',
#   '瑕',
#   'CC',
#   '霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '娇颜',
#   '粉嫩',
#   '保湿',
#   '眼部',
#   '精华',
#   ' ',
#   '四件套',
#   '乳液',
#   '精华',
#   '眼霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '雪润晶采',
#   '眼霜',
#   '15g',
#   ' ',
#   '淡化',
#   '黑眼圈',
#   '细纹',
#   '紧致',
#   ' ',
#   '眼部'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '活泉',
#   '保湿',
#   '修护',
#   '精华',
#   '水',
#   '（',
#   '滋润',
#   '型',
#   '135ml',
#   ' ',
#   '补水',
#   '控油',
#   '爽肤水'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '补水',
#   '洁面乳',
#   ' ',
#   '125g',
#   ' ',
#   '深层',
#   '清洁',
#   '滋润',
#   ' ',
#   '正品',
#   '包邮',
#   '洗面奶',
#   '女',
#   '男'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '深层',
#   '净化',
#   '控油',
#   '凝露',
#   '60g',
#   ' ',
#   '控油',
#   '补水',
#   '保湿',
#   '滋润',
#   ' ',
#   '活泉',
#   '精华',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '活泉',
#   '多效',
#   '精华',
#   '眼霜',
#   '20g',
#   ' ',
#   '淡化',
#   '黑眼圈',
#   '细纹',
#   '紧致',
#   '保湿',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '活泉',
#   '深层',
#   '补水',
#   '酣睡',
#   '膜',
#   ' ',
#   ' ',
#   '补水',
#   '保湿',
#   '免洗',
#   '面膜',
#   ' ',
#   '正品',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '活泉',
#   '保湿',
#   '精华',
#   '套装',
#   ' ',
#   '保湿',
#   '补水',
#   '滋润',
#   '控油',
#   '面部',
#   '护理',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '男士',
#   '面部',
#   '护肤',
#   '套装',
#   ' ',
#   ' ',
#   '洁面',
#   '洗面奶',
#   '爽肤水',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润',
#   '深澈',
#   '精华',
#   '面膜',
#   '贴',
#   '5',
#   '片',
#   ' ',
#   '补水',
#   '面膜',
#   '护肤品',
#   '专柜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白水',
#   '乳',
#   '套装',
#   ' ',
#   '爽肤水',
#   '乳液',
#   '面膜',
#   ' ',
#   '亮肤',
#   '补水',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '套装',
#   '水乳',
#   '/',
#   '霜',
#   '套装',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '淡化',
#   '细纹'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '冰肌',
#   '精华',
#   '套组',
#   ' ',
#   '滋润',
#   '护肤',
#   ' ',
#   '精华',
#   '爽肤水',
#   'BB',
#   '套装'],
#  ['自然', '堂水润', '保湿', '洁面', '套装', ' ', '深层', '清洁', '不', '紧绷', '补水', '保湿', '洁面'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿',
#   '面膜',
#   '5',
#   '片装',
#   ' ',
#   '滋润',
#   '补水',
#   '保湿',
#   '面膜',
#   '贴',
#   ' ',
#   '包邮',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '粉嫩',
#   '保湿',
#   '面膜',
#   '面贴膜',
#   '5',
#   '片',
#   ' ',
#   ' ',
#   '密集',
#   '补水',
#   '修护',
#   '面膜',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '密集',
#   '修护',
#   '滋润',
#   '冰肌',
#   '膜',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '面膜'],
#  ['自然',
#   '堂',
#   '男士',
#   '保湿',
#   '补水',
#   '霜',
#   '矿物',
#   '元素',
#   '滋润',
#   '肌肤',
#   '面霜',
#   '护肤品',
#   ' ',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '控油',
#   '平衡',
#   '爽肤水',
#   '135ml',
#   ' ',
#   '控油',
#   '补水',
#   ' ',
#   '保湿',
#   ' ',
#   '化妆水',
#   '正品',
#   '包邮'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '深层',
#   '补水',
#   '露',
#   ' ',
#   '补水',
#   '保湿',
#   ' ',
#   '平衡',
#   '油性',
#   '肌肤',
#   '化妆品',
#   '护肤',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   'BB',
#   '家族',
#   '润泽',
#   '无瑕',
#   '养护',
#   '粉底液',
#   '遮',
#   '瑕',
#   '粉底液',
#   '遮',
#   '瑕',
#   '调整',
#   '肤色'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '水乳',
#   '套装',
#   ' ',
#   '爽肤水',
#   '冰肌',
#   '水',
#   '乳液',
#   '面霜',
#   '护理',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂水润',
#   '保湿',
#   '面部',
#   '护理',
#   '套装',
#   ' ',
#   '洗面奶',
#   '爽肤水',
#   '乳液',
#   '面霜',
#   '补水',
#   '女'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '保湿',
#   '修护',
#   '精华',
#   '水',
#   '（',
#   '清爽型',
#   '）',
#   '135ml',
#   ' ',
#   ' ',
#   '清爽',
#   '补水',
#   '爽肤水',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '男士',
#   '保湿',
#   '精华',
#   '眼霜',
#   '淡化',
#   '黑眼圈',
#   '细纹',
#   '紧致',
#   '眼部',
#   '护理',
#   '正品'],
#  ['自然',
#   '堂',
#   '男士',
#   '冰川',
#   '控油',
#   '爽肤水',
#   ' ',
#   '补水',
#   '保湿',
#   '控油',
#   '须',
#   '后',
#   '水',
#   '正品',
#   '包邮'],
#  ['自然',
#   '堂',
#   '男士',
#   '控油',
#   '补水',
#   '露',
#   ' ',
#   '补水',
#   '保湿',
#   '控油',
#   '清爽',
#   '男士',
#   '护肤品',
#   '正品'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '补水',
#   '控油',
#   '洁面膏',
#   '（',
#   '泡沫',
#   '型',
#   '）',
#   '110g',
#   ' ',
#   ' ',
#   '深层',
#   '清洁',
#   ' ',
#   '正品',
#   ' ',
#   '包邮'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '深层',
#   '补水',
#   '霜',
#   '50g',
#   ' ',
#   '保湿',
#   '控油',
#   '平衡',
#   '水油',
#   '滋润',
#   '肌肤',
#   ' ',
#   '补水',
#   '面霜',
#   '女'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '加倍',
#   '补水',
#   '乳霜',
#   '60g',
#   ' ',
#   '补水',
#   '保湿',
#   '改善',
#   '肌肤',
#   '干燥',
#   '专柜',
#   '正品',
#   '包邮'],
#  ['自然',
#   '堂',
#   ' ',
#   '活泉',
#   '控油',
#   '净爽',
#   '泡沫',
#   '洁面膏',
#   '110g',
#   ' ',
#   '控油',
#   '补水',
#   ' ',
#   '包邮',
#   ' ',
#   '洗面奶',
#   '女',
#   '男'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '滋润',
#   '保湿',
#   '精华',
#   '霜',
#   'BB',
#   '霜',
#   '35ml',
#   ' ',
#   '补水',
#   '保湿',
#   '隔离',
#   'BB',
#   '霜',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润',
#   '深澈',
#   '皙',
#   '白',
#   '补水',
#   '套装',
#   ' ',
#   '洗面奶',
#   '冰肌',
#   '水',
#   '乳液',
#   '补水',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '冰肌',
#   '滋润',
#   '套装',
#   ' ',
#   '洗面奶',
#   '爽肤水',
#   '乳液',
#   '面霜'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白',
#   '精华',
#   '套装',
#   ' ',
#   '美白',
#   '保湿',
#   '补水',
#   '滋润',
#   '护理',
#   '爽肤水',
#   '精华'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '凝',
#   '时鲜',
#   '颜',
#   '眼部',
#   '精华',
#   '滋养',
#   '套装',
#   ' ',
#   '保湿',
#   '滋润',
#   '精华'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '嫩白',
#   '基础',
#   '三件',
#   '套装',
#   '面部',
#   '护理',
#   '套装',
#   ' ',
#   '滋润',
#   '保湿',
#   '补水',
#   '女'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '男士',
#   '控油',
#   '劲爽',
#   '套装',
#   ' ',
#   '洁面',
#   '爽肤水',
#   '面部',
#   '护理',
#   '男',
#   ' ',
#   '控油',
#   '补水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂光',
#   '透',
#   '无瑕',
#   '矿物',
#   '养护',
#   '两用',
#   '粉饼',
#   '保湿',
#   '修护',
#   '遮',
#   '瑕',
#   '定妆',
#   '彩妆'],
#  ['自然',
#   '堂',
#   '柔润',
#   '细滑妆前',
#   '乳',
#   '修饰',
#   '毛孔',
#   '上妆',
#   '持久',
#   '匀色',
#   '提亮',
#   '隔离',
#   '滋润'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '活泉',
#   '秋冬',
#   '滋养',
#   '控油',
#   '护肤',
#   '套装',
#   ' ',
#   '补水',
#   '控油',
#   '保湿',
#   ' ',
#   '化妆品',
#   '女'],
#  ['自然',
#   '堂',
#   '男士',
#   '洁面',
#   '2',
#   '支装',
#   ' ',
#   '深层',
#   '清洁',
#   '清爽',
#   '控油',
#   '洗面奶',
#   '男士',
#   '正品'],
#  ['自然', '堂植萃', '净澈', '养护', '眼唇', '卸妆液', '深层', '清洁', '眼部', '唇部', '正品', '包邮'],
#  ['自然',
#   '堂',
#   '纤长',
#   '浓密',
#   '养护',
#   '睫毛膏',
#   ' ',
#   '浓密',
#   '丰盈',
#   '持久',
#   '卷',
#   '翘',
#   '彩妆',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂晶透',
#   '无瑕',
#   '散粉',
#   '蜜粉',
#   '定妆',
#   '粉',
#   ' ',
#   '控油',
#   '保湿',
#   '光泽',
#   '美肌',
#   '彩妆',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '翘密',
#   '.',
#   '纤长',
#   '随心',
#   '控',
#   '睫毛膏',
#   '黑色',
#   ' ',
#   '浓密',
#   '卷',
#   '翘',
#   '持久',
#   '定型',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂亲',
#   '蜜亮',
#   '彩',
#   '唇膏',
#   '笔护唇',
#   ' ',
#   '保湿',
#   '滋养',
#   '多色',
#   '口红',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂植萃',
#   '净澈',
#   '养护',
#   '卸妆乳',
#   ' ',
#   '脸部',
#   '卸妆',
#   '温和',
#   '舒缓',
#   '彩妆',
#   '正品',
#   '包邮'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '深邃',
#   '精致',
#   '眼线笔',
#   '黑色',
#   ' ',
#   '持久',
#   '不',
#   '黏腻',
#   '眼部',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '粉嫩',
#   '眼霜',
#   '套装',
#   ' ',
#   '水嫩',
#   '肌肤',
#   ' ',
#   '爽肤水',
#   '乳液',
#   '眼霜'],
#  ['自然',
#   '堂',
#   '活泉',
#   '深层',
#   '补水',
#   '按摩乳',
#   ' ',
#   '保湿',
#   '活肤',
#   '长久',
#   '水嫩',
#   '乳液',
#   '女',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '凝',
#   '时鲜',
#   '颜肌活',
#   '修护',
#   '精华液',
#   '套装',
#   ' ',
#   '淡',
#   '细纹',
#   '暗沉'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '凝',
#   '时鲜',
#   '颜',
#   '冰肌',
#   '水',
#   '套装',
#   ' ',
#   '抗衰',
#   '紧致',
#   '肌肤',
#   ' ',
#   '爽肤水'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂娇颜',
#   '嫩肤',
#   '保湿',
#   '精华',
#   '套装',
#   ' ',
#   '滋润',
#   '保湿',
#   '补水',
#   '面部',
#   '护理',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   '保湿',
#   '补水',
#   '滋润',
#   '呵护',
#   '套装',
#   ' ',
#   '护肤品',
#   '套装',
#   '女',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '雪润皙',
#   '白日',
#   '晚霜',
#   '套装',
#   ' ',
#   '补水',
#   '保湿',
#   '滋润',
#   '面霜',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '滋润',
#   '礼盒',
#   '15',
#   '周年',
#   '定制',
#   '纪念版',
#   '套装'],
#  ['自然',
#   '堂',
#   '自动',
#   '双头',
#   '易画',
#   '眼线笔',
#   ' ',
#   '帖服',
#   '持久',
#   '不',
#   '晕染',
#   '眼线笔',
#   ' ',
#   '眼部'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '炫彩盈',
#   '润唇膏',
#   ' ',
#   '滋润',
#   '保湿',
#   '持久',
#   '唇膏',
#   '多色',
#   '口红',
#   '女',
#   ' ',
#   '彩妆'],
#  ['自然', '堂极细', '流畅', '眼线笔', ' ', '防水', '不', '晕染', '持久', '浓黑', '彩妆', '眼线笔'],
#  ['自然',
#   '堂',
#   '雪域',
#   '倍护',
#   '防晒霜',
#   'SPF30',
#   '+',
#   'PA',
#   '+++',
#   '隔离',
#   '保湿',
#   '防晒',
#   ' ',
#   '正品'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '轻盈',
#   '身体',
#   '防晒乳',
#   '（',
#   '喷雾',
#   '型',
#   '）',
#   'SPF30',
#   '/',
#   'PA',
#   '++',
#   '防晒'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   ' ',
#   '雪域',
#   '冰肌',
#   '晒',
#   '后',
#   '修护露',
#   ' ',
#   '保湿',
#   '晒',
#   '后',
#   '修护',
#   '清爽',
#   '补水',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润晶',
#   '采裸透',
#   '气垫',
#   '霜',
#   ' ',
#   '保湿',
#   '水润',
#   '贴',
#   '妆',
#   '遮',
#   '瑕',
#   ' ',
#   '气垫',
#   'BB',
#   '霜'],
#  ['自然',
#   '堂亮',
#   '眸',
#   '持久',
#   '眼线',
#   '膏',
#   ' ',
#   ' ',
#   '持久',
#   '防水',
#   '不',
#   '晕染',
#   '速',
#   '干眼',
#   '彩妆'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润皙',
#   '白',
#   '旅行装',
#   '三件套',
#   ' ',
#   '补水',
#   '保湿',
#   '亮肤',
#   '体验',
#   '装',
#   '三件套'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂雪润晶',
#   '采裸透',
#   '气垫',
#   '霜',
#   '+',
#   '替换',
#   '装',
#   '保湿',
#   '水润',
#   '贴',
#   '妆',
#   'BB',
#   '霜',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '雪润',
#   '深澈',
#   '皙',
#   '白',
#   '精华液',
#   '套装',
#   ' ',
#   '保湿',
#   '滋润',
#   '面部',
#   '精华'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '雪域',
#   '精粹',
#   '纯粹',
#   '保湿',
#   '滋润',
#   ' ',
#   '呵护',
#   '套装',
#   ' ',
#   '补水',
#   '乳霜',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '凝',
#   '时鲜',
#   '颜',
#   ' ',
#   '滋润',
#   '补水',
#   '呵护',
#   '臻',
#   '选',
#   '套装',
#   ' ',
#   '淡化',
#   '细纹',
#   '补水',
#   '保湿'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '雪润',
#   '净澈',
#   '无瑕',
#   '透白',
#   '套装',
#   ' ',
#   '洗面奶',
#   '爽肤水',
#   'BB',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '【',
#   '预售',
#   '】',
#   '活泉',
#   '润养',
#   '无瑕',
#   '超值',
#   '套装',
#   ' ',
#   '控油',
#   '补水',
#   '保湿',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '彩妆',
#   '护肤',
#   '组合',
#   '套装',
#   ' ',
#   '唇膏',
#   '眼线笔',
#   ' ',
#   '滋润',
#   '套装'],
#  ['CHANDO',
#   '/',
#   '自然',
#   '堂',
#   '护手霜',
#   '3',
#   '支装',
#   '套装',
#   '面膜',
#   ' ',
#   '滋润',
#   '保湿',
#   ' ',
#   '防裂',
#   '修护',
#   '护手霜',
#   '包邮'],
#  ...]

# %%
data['item_name_cut'] = title_cut
data[['title', 'item_name_cut']].head()
# Out:
#                                    title  \
# 0    CHANDO/自然堂 雪域精粹纯粹滋润霜50g 补水保湿 滋润水润面霜
# 1   CHANDO/自然堂凝时鲜颜肌活乳液120ML 淡化细纹补水滋润专柜正品
# 2   CHANDO/自然堂活泉保湿修护精华水（滋润型135ml 补水控油爽肤水
# 3  CHANDO/自然堂 男士劲爽控油洁面膏 100g 深层清洁  男士洗面奶
# 4     CHANDO/自然堂雪域精粹纯粹滋润霜（清爽型）50g补水保湿滋润霜
#
#                                        item_name_cut
# 0  [CHANDO, /, 自然, 堂,  , 雪域, 精粹, 纯粹, 滋润霜, 50g,  ,...
# 1  [CHANDO, /, 自然, 堂, 凝, 时鲜, 颜肌活, 乳液, 120ML,  , 淡...
# 2  [CHANDO, /, 自然, 堂, 活泉, 保湿, 修护, 精华, 水, （, 滋润, 型...
# 3  [CHANDO, /, 自然, 堂,  , 男士, 劲爽, 控油, 洁面膏,  , 100g...
# 4  [CHANDO, /, 自然, 堂, 雪域, 精粹, 纯粹, 滋润霜, （, 清爽型, ）,...

# %%
# 给商品添加分类
sub_type = [] # 子类别
main_type = [] # 主类别
basic_config_data = """护肤品	套装	套装							
护肤品	乳液类	乳液	美白乳	润肤乳	凝乳	柔肤液'	亮肤乳	菁华乳	修护乳
护肤品	眼部护理	眼霜	眼部精华	眼膜					
护肤品	面膜类	面膜													
护肤品	清洁类	洗面	洁面	清洁	卸妆	洁颜	洗颜	去角质	磨砂						
护肤品	化妆水	化妆水	爽肤水	柔肤水	补水露	凝露	柔肤液	精粹水	亮肤水	润肤水	保湿水	菁华水	保湿喷雾	舒缓喷雾
护肤品	面霜类	面霜	日霜	晚霜	柔肤霜	滋润霜	保湿霜	凝霜	日间霜	晚间霜	乳霜	修护霜	亮肤霜	底霜	菁华霜
护肤品	精华类	精华液	精华水	精华露	精华素										
护肤品	防晒类	防晒霜	防晒喷雾												
化妆品	口红类	唇釉	口红	唇彩											
化妆品	底妆类	散粉	蜜粉	粉底液	定妆粉 	气垫	粉饼	BB	CC	遮瑕	粉霜	粉底膏	粉底霜		
化妆品	眼部彩妆	眉粉	染眉膏	眼线	眼影	睫毛膏									
化妆品	修容类	鼻影	修容粉	高光	腮红										
其他	其他	其他"""

# %%
category_config_map = {}
for config_line in basic_config_data.split('\n'):
    basic_category_list = config_line.strip().strip('\n').strip('\t').split('\t')
    main_category = basic_category_list[0]
    sub_category = basic_category_list[1]
    unit_category_list = basic_category_list[2:]
    for unit_category in unit_category_list:
        if unit_category and unit_category.strip().strip('\t'):
            category_config_map[unit_category] = (main_category, sub_category)

# %%
category_config_map
# Out:
# {'套装': ('护肤品', '套装'),
#  '乳液': ('护肤品', '乳液类'),
#  '美白乳': ('护肤品', '乳液类'),
#  '润肤乳': ('护肤品', '乳液类'),
#  '凝乳': ('护肤品', '乳液类'),
#  "柔肤液'": ('护肤品', '乳液类'),
#  '亮肤乳': ('护肤品', '乳液类'),
#  '菁华乳': ('护肤品', '乳液类'),
#  '修护乳': ('护肤品', '乳液类'),
#  '眼霜': ('护肤品', '眼部护理'),
#  '眼部精华': ('护肤品', '眼部护理'),
#  '眼膜': ('护肤品', '眼部护理'),
#  '面膜': ('护肤品', '面膜类'),
#  '洗面': ('护肤品', '清洁类'),
#  '洁面': ('护肤品', '清洁类'),
#  '清洁': ('护肤品', '清洁类'),
#  '卸妆': ('护肤品', '清洁类'),
#  '洁颜': ('护肤品', '清洁类'),
#  '洗颜': ('护肤品', '清洁类'),
#  '去角质': ('护肤品', '清洁类'),
#  '磨砂': ('护肤品', '清洁类'),
#  '化妆水': ('护肤品', '化妆水'),
#  '爽肤水': ('护肤品', '化妆水'),
#  '柔肤水': ('护肤品', '化妆水'),
#  '补水露': ('护肤品', '化妆水'),
#  '凝露': ('护肤品', '化妆水'),
#  '柔肤液': ('护肤品', '化妆水'),
#  '精粹水': ('护肤品', '化妆水'),
#  '亮肤水': ('护肤品', '化妆水'),
#  '润肤水': ('护肤品', '化妆水'),
#  '保湿水': ('护肤品', '化妆水'),
#  '菁华水': ('护肤品', '化妆水'),
#  '保湿喷雾': ('护肤品', '化妆水'),
#  '舒缓喷雾': ('护肤品', '化妆水'),
#  '面霜': ('护肤品', '面霜类'),
#  '日霜': ('护肤品', '面霜类'),
#  '晚霜': ('护肤品', '面霜类'),
#  '柔肤霜': ('护肤品', '面霜类'),
#  '滋润霜': ('护肤品', '面霜类'),
#  '保湿霜': ('护肤品', '面霜类'),
#  '凝霜': ('护肤品', '面霜类'),
#  '日间霜': ('护肤品', '面霜类'),
#  '晚间霜': ('护肤品', '面霜类'),
#  '乳霜': ('护肤品', '面霜类'),
#  '修护霜': ('护肤品', '面霜类'),
#  '亮肤霜': ('护肤品', '面霜类'),
#  '底霜': ('护肤品', '面霜类'),
#  '菁华霜': ('护肤品', '面霜类'),
#  '精华液': ('护肤品', '精华类'),
#  '精华水': ('护肤品', '精华类'),
#  '精华露': ('护肤品', '精华类'),
#  '精华素': ('护肤品', '精华类'),
#  '防晒霜': ('护肤品', '防晒类'),
#  '防晒喷雾': ('护肤品', '防晒类'),
#  '唇釉': ('化妆品', '口红类'),
#  '口红': ('化妆品', '口红类'),
#  '唇彩': ('化妆品', '口红类'),
#  '散粉': ('化妆品', '底妆类'),
#  '蜜粉': ('化妆品', '底妆类'),
#  '粉底液': ('化妆品', '底妆类'),
#  '定妆粉 ': ('化妆品', '底妆类'),
#  '气垫': ('化妆品', '底妆类'),
#  '粉饼': ('化妆品', '底妆类'),
#  'BB': ('化妆品', '底妆类'),
#  'CC': ('化妆品', '底妆类'),
#  '遮瑕': ('化妆品', '底妆类'),
#  '粉霜': ('化妆品', '底妆类'),
#  '粉底膏': ('化妆品', '底妆类'),
#  '粉底霜': ('化妆品', '底妆类'),
#  '眉粉': ('化妆品', '眼部彩妆'),
#  '染眉膏': ('化妆品', '眼部彩妆'),
#  '眼线': ('化妆品', '眼部彩妆'),
#  '眼影': ('化妆品', '眼部彩妆'),
#  '睫毛膏': ('化妆品', '眼部彩妆'),
#  '鼻影': ('化妆品', '修容类'),
#  '修容粉': ('化妆品', '修容类'),
#  '高光': ('化妆品', '修容类'),
#  '腮红': ('化妆品', '修容类'),
#  '其他': ('其他', '其他')}

# %%
for i in range(len(data)):
    exist = False
    for temp in data.item_name_cut[i]:
        if temp in category_config_map:
            sub_type.append(category_config_map.get(temp)[1])
            main_type.append(category_config_map.get(temp)[0])
            exist = True
            break
    if not exist:
        sub_type.append('其他')
        main_type.append('其他')

print(len(sub_type), len(main_type), len(data))
# Out:
# 27512 27512 27512

# %% [markdown]
# #### （2）将子类别sub_type新增为一列

# %%
data['sub_type'] = sub_type

# %% [markdown]
# #### （3）将主类别main_type新增为一列

# %%
data['main_type'] = main_type

# %%
data['sub_type'].value_counts()
# Out:
# 其他      8085
# 套装      3465
# 清洁类     2639
# 面霜类     2443
# 化妆水     1774
# 底妆类     1716
# 面膜类     1551
# 乳液类     1226
# 眼部彩妆    1151
# 眼部护理    1111
# 口红类      788
# 精华类      783
# 防晒类      494
# 修容类      286
# Name: sub_type, dtype: int64

# %%
data['main_type'].value_counts()
# Out:
# 护肤品    15486
# 其他      8085
# 化妆品     3941
# Name: main_type, dtype: int64

# %% [markdown]
# #### （4）将“是否男士专用”新增为一列

# %%
gender = []
for i in range(len(data)):
    if '男' in data.item_name_cut[i]:
        gender.append('是')
    elif '男士' in data.item_name_cut[i]:
        gender.append('是')
    elif '男生' in data.item_name_cut[i]:
        gender.append('是')
    else:
        gender.append('否')

# %%
data['是否男士专用'] = gender
data['是否男士专用'].value_counts()
# Out:
# 否    25310
# 是     2202
# Name: 是否男士专用, dtype: int64

# %% [markdown]
# #### （5）新增销售额、购买日期（天）为一列
# #### 新增销售额为一列

# %%
# 销售额 = 销售量 * 价格
data['销售额'] = data.sale_count * data.price

# %% [markdown]
# #### 新增购买日期为一列

# %%
# 转换时间格式
data['update_time'] = pd.to_datetime(data['update_time'])
data['update_time']
# Out:
# 0       2016-11-14
# 1       2016-11-14
# 2       2016-11-14
# 3       2016-11-14
# 4       2016-11-14
#            ...
# 27507   2016-11-05
# 27508   2016-11-05
# 27509   2016-11-05
# 27510   2016-11-05
# 27511   2016-11-05
# Name: update_time, Length: 27512, dtype: datetime64[ns]

# %%
# 将时间设置为新的index
data.set_index('update_time', inplace=True)

# %%
# 新增时间‘天’为一列
data['day'] = data.index.day

# 删除中文分词的一列
data.drop('item_name_cut', axis=1, inplace=True)

# %% [markdown]
# #### （6）查看最终数据表格

# %%
data.head()
# Out:
#                        id                                  title  price  \
# update_time
# 2016-11-14   A18164178225    CHANDO/自然堂 雪域精粹纯粹滋润霜50g 补水保湿 滋润水润面霜  139.0
# 2016-11-14   A18177105952   CHANDO/自然堂凝时鲜颜肌活乳液120ML 淡化细纹补水滋润专柜正品  194.0
# 2016-11-14   A18177226992   CHANDO/自然堂活泉保湿修护精华水（滋润型135ml 补水控油爽肤水   99.0
# 2016-11-14   A18178033846  CHANDO/自然堂 男士劲爽控油洁面膏 100g 深层清洁  男士洗面奶   38.0
# 2016-11-14   A18178045259     CHANDO/自然堂雪域精粹纯粹滋润霜（清爽型）50g补水保湿滋润霜  139.0
#
#              sale_count  comment_count   店名 sub_type main_type 是否男士专用  \
# update_time
# 2016-11-14      26719.0         2704.0  自然堂      面霜类       护肤品      否
# 2016-11-14       8122.0         1492.0  自然堂      乳液类       护肤品      否
# 2016-11-14      12668.0          589.0  自然堂      化妆水       护肤品      否
# 2016-11-14      25805.0         4287.0  自然堂      清洁类       护肤品      是
# 2016-11-14       5196.0          618.0  自然堂      面霜类       护肤品      否
#
#                    销售额  day
# update_time
# 2016-11-14   3713941.0   14
# 2016-11-14   1575668.0   14
# 2016-11-14   1254132.0   14
# 2016-11-14    980590.0   14
# 2016-11-14    722244.0   14

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 27512 entries, 2016-11-14 to 2016-11-05
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             27512 non-null  object
#  1   title          27512 non-null  object
#  2   price          27512 non-null  float64
#  3   sale_count     27512 non-null  float64
#  4   comment_count  27512 non-null  float64
#  5   店名             27512 non-null  object
#  6   sub_type       27512 non-null  object
#  7   main_type      27512 non-null  object
#  8   是否男士专用         27512 non-null  object
#  9   销售额            27512 non-null  float64
#  10  day            27512 non-null  int64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 2.5+ MB

# %%
# 保存清理好的数据为Excel格式
data.to_excel('data/清洗好的美妆销售数据.xls', sheet_name='clean_data')

# %% [markdown]
# ## 3. 数据探索

# %%
import seaborn as sns
# %matplotlib inline

# %%
data.columns
# Out:
# Index(['id', 'title', 'price', 'sale_count', 'comment_count', '店名', 'sub_type',
#        'main_type', '是否男士专用', '销售额', 'day'],
#       dtype='object')

# %% [markdown]
# ### 3.1 各品牌SKU数

# %%
# 解决负号‘-’显示为方块的问题
plt.rcParams['axes.unicode_minus']=False
plt.rcParams['font.sans-serif'] = ['SimHei']

plt.figure(figsize=(8,6))
# 计算各店铺的商品数量
data['店名'].value_counts().sort_values(ascending=False).plot.bar(width=0.8, alpha=0.6, color='b')
plt.title('各品牌SKU数', fontsize=18)
plt.ylabel('商品数量', fontsize=14)
plt.show()

# %% [markdown]
# * 悦诗风铃的商品数量最多，其次为佰草集、欧莱雅

# %% [markdown]
# ### 3.2 品牌总销量和总销售额

# %%
fig, axes = plt.subplots(1,2, figsize=(12,10))

ax1 = data.groupby('店名').sale_count.sum().sort_values(ascending=True).plot(kind='barh', width=0.6, ax=axes[0])
ax1.set_title('品牌总销售量')
ax1.set_xlabel('总销售量')

ax2 = data.groupby('店名').销售额.sum().sort_values(ascending=True).plot(kind='barh', width=0.6, ax=axes[1])
ax2.set_title('品牌总销售额')
ax2.set_xlabel('总销售额')

plt.subplots_adjust(wspace=0.4)
plt.show()

# %% [markdown]
# ### 3.3 各类别的销售量、销售额情况

# %%
fig, axes = plt.subplots(1,2,figsize=(12,5))

data1 = data.groupby('main_type').sale_count.sum()
ax1 = data1.plot(kind='pie', ax=axes[0], autopct='%.1f%%', # 设置百分比的格式，这里保留一位小数
                pctdistance=0.8, # 百分比标签与圆心的距离
                labels=data1.index,
                labeldistance=1.05, # 标签与圆心的距离
                startangle=60,  # 初始角度
                radius=1.1,  # 圆饼的半径
                counterclock=False,  # 是否逆时针
                wedgeprops={'linewidth':1.2, 'edgecolor':'k'},  # 设置饼图内外边界的属性值
                textprops={'fontsize':10, 'color':'k'})  # 设置文本标签的属性值
ax1.set_title('主类别销售量占比')

data2 = data.groupby('sub_type').sale_count.sum()
ax2 = data2.plot(kind='pie', ax=axes[1], autopct='%.1f%%',
                pctdistance=0.8,
                labels=data2.index,
                labeldistance=1.05,
                startangle=60,
                radius=1.1,
                counterclock=False,
                wedgeprops={'linewidth':1.2, 'edgecolor':'k'},
                textprops={'fontsize':10, 'color':'k'})
ax2.set_title('子类别销售量占比')

plt.subplots_adjust(wspace=0.4)
plt.show()

# %% [markdown]
# * 从主类别销售量占比情况来看，护肤品的销量远大于化妆品；
# * 从子类别销售量占比情况来看，护肤品中，套装、清洁类、面膜、面露等销量最多；而化妆品中，底妆类、口红的销量最多。

# %%
plt.figure(figsize=(14,6))
sns.barplot(x='店名', y='sale_count', hue='main_type', data=data, saturation=0.75, ci=0)
plt.title('各品牌各种类的总销量')
plt.ylabel('销量')
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.barplot(x='店名', y='销售额', hue='main_type', data=data, saturation=0.75, ci=0)
plt.title('各品牌各种类的总销售额')
plt.ylabel('销售额')
plt.show()

# %% [markdown]
# * 各品牌的化妆品、护肤品销量、销售情况均不一样，这与品牌的定位有关，有的品牌主打化妆品，化妆品表现好很多，如蜜丝佛陀。主打护肤品的品牌，护肤品的销量销售额会表现好很多，如欧莱雅，相宜本草等。有的品牌如悦诗风铃、雪花秀、兰蔻等化妆品和护肤品的销售都不错。

# %%
plt.figure(figsize=(16,6))
sns.barplot(x='店名', y='sale_count', hue='sub_type', data=data, saturation=0.75, ci=0)
plt.title('各品牌各种类的总销量')
plt.ylabel('销量')
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.barplot(x='店名', y='销售额', hue='sub_type', data=data, saturation=0.75, ci=0)
plt.title('各品牌各种类的总销售额')
plt.ylabel('销售额')
plt.show()

# %% [markdown]
# ### 3.4 各品牌热度

# %%
plt.figure(figsize=(12,6))
data.groupby('店名').comment_count.mean().sort_values(ascending=False).plot(kind='bar', width=0.8)
plt.title('各品牌商品的平均评论数')
plt.ylabel('评论数')
plt.show()

# %%
plt.figure(figsize=(12,10))

x = data.groupby('店名')['sale_count'].mean()
y = data.groupby('店名')['comment_count'].mean()
s = data.groupby('店名')['price'].mean()
txt = data.groupby('店名').id.count().index

sns.scatterplot(x, y, size=s, hue=s, sizes=(100,1500), data=data)

for i in range(len(txt)):
     plt.annotate(txt[i], xy=(x[i], y[i]))
        
plt.ylabel('热度')
plt.xlabel('销量')

plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# #### 由上图所示：越靠上的品牌热度越高，越靠右的品牌销量越高，颜色越深圈越大价格越高
# * 热度与销量呈现一定的正相关
# * 美宝莲热度第一，销量第二，妮维雅热度第二，销量第四，两者价格均相对较低
# * 价格低的品牌热度和销量相对较高，价格高的品牌热度和销量相对较低，说明价格在热度和销量中有一定影响；

# %% [markdown]
# ### 3.5 各品牌价格

# %%
# 查看价格的箱形图
plt.figure(figsize=(14,6))
sns.boxplot(x='店名', y='price', data=data)
plt.ylim(0, 3000) # 如果不限制，就不容易看清箱形，所以把Y轴刻度缩小为0-3000
plt.show()

# %%
avg_price = data.groupby('店名').price.mean()
avg_price
# Out:
# 店名
# SKII    1011.727079
# 佰草集      289.823171
# 倩碧       346.092190
# 兰芝       356.615809
# 兰蔻       756.400778
# 妮维雅       73.789053
# 娇兰      1361.043588
# 悦诗风吟     121.245945
# 植村秀      311.786667
# 欧珀莱      276.218543
# 欧莱雅      167.282698
# 玉兰油      329.657294
# 相宜本草     122.958446
# 美加净       44.694619
# 美宝莲      148.757576
# 自然堂      180.130213
# 薇姿       281.085791
# 蜜丝佛陀     142.118894
# 资生堂      577.438490
# 雅漾       212.618401
# 雅诗兰黛     872.470718
# 雪花秀      901.082873
# Name: price, dtype: float64

# %%
fig = plt.figure(figsize=(12,6))
avg_price.sort_values(ascending=False).plot(kind='bar', width=0.8, alpha=0.6, color='b', label='各品牌平均价格')
y = data['price'].mean()
plt.axhline(y, color='r', label='全品牌平均价格')
plt.ylabel('各品牌平均价格')
plt.title('各品牌产品的平均价格', fontsize=24)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# * 娇兰、SKII、雪花秀、雅诗兰黛、兰蔻、资生堂这几个国际大牌的产品价格很高，产品平均价格都在500以上，都是一线大牌；
# * 兰芝、倩碧、玉兰油、植村秀、佰草集、薇姿、雅漾的平均价格在300-400元左右，其中佰草集是最贵的国货品牌；
# * 美加净作为国货品牌，性价比高，平均价格最低，妮维雅的平均价格第二低，在100元左右；
# * 全品牌平均价格低于400元，除了前五个国际大牌其余品牌的平均价格都低于全品牌平均价格；

# %%
plt.figure(figsize=(12,10))

x = data.groupby('店名')['sale_count'].mean()
y = data.groupby('店名')['销售额'].mean()
s = avg_price
txt = data.groupby('店名').id.count().index

sns.scatterplot(x, y, size=s, sizes=(100,1500), marker='v', alpha=0.5, color='b', data=data)

for i in range(len(txt)):
    plt.annotate(txt[i], xy=(x[i], y[i]), xytext=(x[i]+0.2, y[i]+0.2))  # 在散点后面增加品牌信息的标签

plt.ylabel('销售额')
plt.xlabel('销量')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### 由上图所示，越靠上代表销售额越高，越靠左代表销量越高，图形越大代表平均价格越高
#
# * 销售量和销售额呈现正相关；
# * 相宜本草、美宝莲、蜜丝佛陀销量和销售额位居前三，且平均价格居中；
# * 说明销量销售额与价格有很重要的联系；

# %% [markdown]
# ### 3.6 男性护肤品销量情况

# %%
gender_data = data[data['是否男士专用']=='是']
gender_data_1 = gender_data[(gender_data.main_type == '护肤品')|(gender_data.main_type=='化妆品')]
plt.figure(figsize=(12,6))
sns.barplot(x='店名', y='sale_count', hue='main_type', data=gender_data_1, saturation=0.75, ci=0)
plt.show()

# %%
f,[ax1,ax2] = plt.subplots(1,2,figsize=(12,6))
gender_data.groupby('店名').sale_count.sum().sort_values(ascending=True).plot(kind='barh', width=0.8, ax=ax1)
ax1.set_title('男士护肤品销量排名')

gender_data.groupby('店名').销售额.sum().sort_values(ascending=True).plot(kind='barh', width=0.8, ax=ax2)
ax2.set_title('男士护肤品销售额排名')

plt.subplots_adjust(wspace=0.4)
plt.show()

# %% [markdown]
# * 男士购买的大多是护肤品
# * 妮维雅是男生护肤品中销量遥遥领先的品牌，第二第三分别为欧莱雅、相宜本草;

# %% [markdown]
# ### 3.7 分析时间与销量的关系，体现购买高峰期

# %%
from matplotlib.pyplot import MultipleLocator
plt.figure(figsize=(12,6))
data.groupby('day').sale_count.sum().plot()
plt.grid(linestyle='-.', color='gray', axis='x', alpha=0.5)
x_major_locator = MultipleLocator(1)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.xlabel('日期（11月）')
plt.ylabel('销量')
plt.show()

# %% [markdown]
# * 淘宝化妆品的购买高峰在11号前几天，可能是双十一之前商家提前预热，已经有很大的优惠了，消费者的购物欲望强烈；
# * 双十一当天，销量最低，可能是消费者为了避免网络高峰，在双11号之前提前购买了；
# * 双十一之后的3天，销量远不如双十一之前了，但也逐步增长了，可能是商家持续打折有优惠，以及消费者的购物余热起作用。

# %% [markdown]
# ### 总结
# * 美妆类别中护肤品销量远大于化妆品，其中清洁类、化妆水、面霜等基础护肤类销量最高；
# * 男士购买美妆集中在护肤品类，其中妮维雅品牌是最受男士喜爱的品牌；
# * 价格和热度对销售量有关联，平价基础产品是大多数消费者的选择；
# * 由于商家在双十一提前预热，巨大的优惠力度和为了避免网络高峰，不少消费者选择提前消费，销量高峰出现在双十一前几天；双十一后3天商家持续打折优惠，消费者还保有购物余热，但远不如双十一之前。

# %% [markdown]
# ### 建议
# * 消费者对产品价格和热度关注度较高，品牌可以适当调整产品价格并通过诸如网络社交平台的方式提高品牌热度；
# * 对于男性消费者，品牌可以定向推荐平价基础护肤产品，在销量中可以看到也有一部分男性购买化妆品，品牌可以在护肤品中适当捆绑化妆品产品带动消费；
# * 消费者购买欲望并不集中在双十一当天，商家可以提前预热加大优惠力度刺激消费者提前消费，避免网络高峰。
